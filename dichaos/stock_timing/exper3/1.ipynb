# %%
import pandas as pd

# %%
pd.read_csv('1.csv',index_col=0).rename(
    columns={'index':'trade_date','0':'ret'}).set_index('trade_date').cumsum().plot(title='cumulative return')
# Out:
# <Axes: title={'center': 'cumulative return'}, xlabel='trade_date'>
