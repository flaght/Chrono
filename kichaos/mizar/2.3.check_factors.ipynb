# %%
import os
import pandas as pd
import numpy as np
import datetime

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from alphacopilot.calendars.api import *
from kdutils.macro2 import *

# %%
method = 'aicso4'
g_instruments = 'rbb'
horizon = 1
category = 1
types = 'o2o'
freq = 5
train_params = {
    'window': 3,
    'nc': 1,
    'freq': freq,
    'train_days': 60,
    'val_days': 5,
    'test_days': freq,
    'past_days': 250
}

dirs = os.path.join(
    base_path, method, 'normal', g_instruments, 'rolling', 'normal_factors3',
    "{0}_{1}".format(category, horizon),
    "{0}_{1}_{2}_{3}_{4}".format(str(train_params['freq']),
                                 str(train_params['train_days']),
                                 str(train_params['val_days']),
                                 str(train_params['nc']), str(0)))

# %%
i = 49
train1 = pd.read_feather(os.path.join(dirs, "normal_factors_train_{0}.feather".format(i)))
val1 = pd.read_feather(os.path.join(dirs, "normal_factors_val_{0}.feather".format(i)))
test1 = pd.read_feather(os.path.join(dirs, "normal_factors_test_{0}.feather".format(i)))

# %%
pd.read_feather(os.path.join(dirs, "report_factors_train_{0}.feather".format(49)))
# Out:
#     index                                            actions final_status  \
# 0       0  [Winsorization ((0.01, 0.01)) 应用. 偏度 -1.84->0....     保留 (已修正)
# 1       1  [Winsorization ((0.01, 0.01)) 应用. 偏度 -1.61->0....     保留 (已修正)
# 2       2  [Winsorization ((0.01, 0.01)) 应用. 偏度 0.17->-0....     保留 (已修正)
# 3       3  [Winsorization ((0.01, 0.01)) 应用. 偏度 -0.04->-0...     保留 (已修正)
# 4       4  [Winsorization ((0.01, 0.01)) 应用. 偏度 2.48->0.3...     保留 (已修正)
# ..    ...                                                ...          ...
# 83     83  [Winsorization ((0.01, 0.01)) 应用. 偏度 -0.67->-0...     保留 (已修正)
# 84     84  [Winsorization ((0.01, 0.01)) 应用. 偏度 -0.25->-0...     保留 (已修正)
# 85     85  [Winsorization ((0.01, 0.01)) 应用. 偏度 -1.51->-0...     保留 (已修正)
# 86     86  [Winsorization ((0.01, 0.01)) 应用. 偏度 -1.51->-0...     保留 (已修正)
# 87     87  [Winsorization ((0.01, 0.01)) 应用. 偏度 -0.06->0....     保留 (已修正)
#
#     status_value                              initial_stats_summary  \
# ...

# %%
test1
# Out:
#               trade_time code  tn003_5_5_10_15_1  tn003_10_5_10_15_1  \
# 0    2025-04-24 09:01:00   RB          -0.760387           -0.528564
# 1    2025-04-24 09:02:00   RB          -1.328749           -0.989288
# 2    2025-04-24 09:03:00   RB          -1.817889           -1.440941
# 3    2025-04-24 09:04:00   RB          -1.999121           -1.712313
# 4    2025-04-24 09:05:00   RB          -2.125012           -1.937781
# ...                  ...  ...                ...                 ...
# 1602 2025-04-30 14:54:00   RB          -0.071788           -0.249713
# 1603 2025-04-30 14:55:00   RB          -0.029900           -0.192078
# 1604 2025-04-30 14:56:00   RB          -0.129180           -0.231120
# 1605 2025-04-30 14:57:00   RB          -0.155932           -0.236342
# 1606 2025-04-30 14:58:00   RB          -0.145851           -0.221698
#
#       tn003_5_5_10_15_0  tn003_10_5_10_15_0  tn004_5_10_1  tn004_10_15_1  \
# ...

# %%
features = test1.columns[2:-1]
features
# Out:
# Index(['tn003_5_5_10_15_1', 'tn003_10_5_10_15_1', 'tn003_5_5_10_15_0',
#        'tn003_10_5_10_15_0', 'tn004_5_10_1', 'tn004_10_15_1', 'tn004_5_10_0',
#        'oi003_5_10_1', 'oi003_5_10_0', 'oi004_5_10_0', 'oi022_5_10_1',
#        'oi023_5_10_1', 'oi023_10_15_1', 'oi023_5_10_0', 'oi031_5_10_1',
#        'oi032_5_5_10_1', 'oi032_10_10_15_1', 'oi033_5_10_1', 'oi034_5_10_1',
#        'oi034_5_10_0', 'oi037_5_10_1', 'oi037_10_15_1', 'oi037_5_10_0',
#        'oi039_5_10_1', 'oi039_5_10_0', 'oi042_5_10_1', 'oi042_10_15_1',
#        'oi042_5_10_0', 'tc003_5_10_0', 'tc003_5_10_1', 'tc005_5_5_10_0',
#        'tc006_5_10_0', 'tc006_5_10_1', 'tc007_5_10_1', 'tc008_5_10_0',
#        'tc008_5_10_1', 'tc012_5_5_10_0', 'tc013_5_10_0', 'tc013_5_10_1',
#        'tc014_5_5_10_0', 'tc015_10_15_1', 'tc015_5_10_0', 'tc015_5_10_1',
#        'dv002_5_10_1', 'dv002_5_10_0', 'db001_5_10_1', 'db005_5_10_1',
#        'db007_5_10_0', 'db007_5_10_1', 'cj010_5_10_1', 'cj011_10_15_1',
# ...

# %%
factor_name = 'oi022_5_10_1'#features[-2]
factor_name
# Out:
# 'oi022_5_10_1'

# %% [markdown]
# #### 均值分布

# %%
#### 整体均值
####
'''
所有三个子集的均值都非常接近0，这符合Z-score标准化的预期效果（训练集均值为0，校验/测试集均值取决于其与训练集分布的相似度）。
校验集和测试集的均值与训练集的均值（理论上为0）差异很小，说明在这几个子集之间，该特征的中心位置没有发生剧烈的、系统性的变化。
'''
train_mean = train1[factor_name].mean()
val_mean = val1[factor_name].mean()
test_mean = test1[factor_name].mean()
print("train_mean:{0}\nval_mean:{1}\ntest_mean:{2}".format(
    train_mean,val_mean,test_mean
))
# Out:
# train_mean:-1.606685328424398e-16
# val_mean:0.2000779829599305
# test_mean:-0.008411493960595637

# %%
### 滚动均值
'''
滚动均值的整体平均水平在所有子集上都接近0，符合预期
若训练集上滚动均值的极值范围远大于校验集和测试集。
这可能意味着训练集覆盖了更极端的短期趋势，或者模型可能学习到了一些在校验/测试集上不那么常见的模式
'''
window = 60 ## 20
pos = len(test1) - window
train_mean = train1[factor_name].rolling(window).mean()
val_mean = val1[factor_name].rolling(window).mean()
test_mean = test1[factor_name].rolling(window).mean()
print("""
      train mean  max:{0},min:{1},mean:{2},std:{3}
      val mean  max:{4},min:{5},mean:{6},std:{7}
      test mean  max:{8},min:{9},mean:{10},std:{11}
      """.format(
          train_mean.max(),train_mean.min(),train_mean.mean(),train_mean.std(),
          val_mean.max(),val_mean.min(),val_mean.mean(),val_mean.std(),
          test_mean.max(),test_mean.min(),test_mean.mean(),test_mean.std(),

      ))

pd.concat([train_mean[-pos:].reset_index(drop=True),
           val_mean[-pos:].reset_index(drop=True),
           test_mean[-pos:].reset_index(drop=True)],axis=1).plot(figsize=(6,3))
# Out:
#       train mean  max:1.638513766851508,min:-1.9689073916340034,mean:-0.000541823314889053,std:0.47711681775205583
#       val mean  max:1.3755384177396004,min:-1.290831525347296,mean:0.21273713865456376,std:0.4871686306316852
#       test mean  max:1.1458175224314362,min:-1.0102962551706525,mean:-0.032851188110885166,std:0.4247101997845714
# <Axes: >

# %% [markdown]
# #### 标准差

# %%
### 置信区间
from scipy import stats
### 标准化后的数据不适和宜相对宽度
def confidence_func(data, confidence_level=0.95, name="训练集"):
    #### 置信区间
    mean_val = data.mean()
    std_err_mean = data.sem() # 标准误差

    ## 需要确保 std_err_mean 大于0 即标准误差有效
    mean_ci_lower, mean_ci_upper = stats.t.interval(confidence_level, len(data) - 1, 
                                                loc=mean_val, scale=std_err_mean)
    print(f"{name} 均值: {mean_val:.4f}")
    print(f"{name} 均值的 {confidence_level*100:.0f}% 置信区间: [{mean_ci_lower:.4f}, {mean_ci_upper:.4f}]")

    mean_ci_width = mean_ci_upper - mean_ci_lower
    relative_width_mean = mean_ci_width / abs(mean_val) # 使用绝对值，因为均值可能为负
    print(f"{name} 均值置信区间的绝对宽度: {mean_ci_width:.4f}")
    print(f"{name}  均值置信区间的相对宽度 (宽度/|均值|): {relative_width_mean:.4%}")
    print("\n\n")

confidence_func(train1[factor_name], name="训练集")
confidence_func(val1[factor_name], name="校验集")
confidence_func(test1[factor_name], name="测试集")
# Out:
# 训练集 均值: -0.0028
# 训练集 均值的 95% 置信区间: [-0.0180, 0.0125]
# 训练集 均值置信区间的绝对宽度: 0.0305
# 训练集  均值置信区间的相对宽度 (宽度/|均值|): 1099.7361%
#
#
#
# 校验集 均值: 0.0036
# 校验集 均值的 95% 置信区间: [-0.0390, 0.0463]
# 校验集 均值置信区间的绝对宽度: 0.0854
# 校验集  均值置信区间的相对宽度 (宽度/|均值|): 2339.3708%
#
#
#
# 测试集 均值: 0.0109
# 测试集 均值的 95% 置信区间: [-0.0322, 0.0540]
# 测试集 均值置信区间的绝对宽度: 0.0861
# 测试集  均值置信区间的相对宽度 (宽度/|均值|): 791.0408%

# %%
### 与均值比较 CV可以衡量相对波动性， 表明相对于均值而言，标准差很大
### ** 特征几乎没有变化，可能不包含任何预测信息
## 特征可能噪声过大，或者包含极端异常值，需要清洗或
## 指导意见
## 不适合标准化的数据

def cv_func(data, name='train'):
    cv1 = data.std()/np.abs(data.mean())
    if cv1 < 0.1:
        print(f"cv: {cv1}  {name} data has low relative volatility.")
    elif 0.1 <= cv1 < 0.3:
        print(f"cv: {cv1}  {name} data has moderate relative volatility.")
    else:
        print(f"cv: {cv1}  {name} data has high relative volatility.")

cv_func(data=train1[factor_name], name='train')
cv_func(data=val1[factor_name], name='val')
cv_func(data=test1[factor_name], name='test')
# Out:
# cv: 401.8587755541969  train data has high relative volatility.
# cv: 248.0503883025803  val data has high relative volatility.
# cv: 80.83534667231046  test data has high relative volatility.

# %% [markdown]
# #### 偏度

# %%
from scipy.stats import skew

# %%
def evaluate_skewness(data_series, feature_name="Feature"):
    """
    计算数据序列的偏度，并根据经验法则进行评估。
    """
    s = skew(data_series.dropna()) # dropna以防有缺失值影响计算

    print(f"\n--- {feature_name} 偏度分析 ---")
    print(f"偏度 (Skewness): {s:.4f}")

    abs_s = abs(s)
    if abs_s < 0.5:
        interpretation = "分布近似对称 (Approx. Symmetrical)"
    elif 0.5 <= abs_s < 1:
        interpretation = "分布中等程度偏斜 (Moderately Skewed)"
    else: # abs_s >= 1
        interpretation = "分布高度偏斜 (Highly Skewed)"

    if s > 0.05: # 加一个小阈值避免非常接近0的也被判为正偏
        direction = "正偏/右偏 (Right-skewed)"
    elif s < -0.05:
        direction = "负偏/左偏 (Left-skewed)"
    else:
        direction = "接近对称 (Nearly Symmetrical)"

    print(f"评估: {interpretation}")
    if interpretation != "分布近似对称 (Approx. Symmetrical)":
        print(f"偏斜方向: {direction}")

    # 提醒潜在的模型影响
    if abs_s >= 1:
        print("提醒: 高度偏斜可能影响某些依赖数据对称性的模型 (如线性回归的OLS假设)。")
    elif 0.5 <= abs_s < 1:
        print("提醒: 中等偏斜，根据模型需求，可能需要考虑数据转换。")

    return s, interpretation, direction

# %%
import seaborn as sns
import matplotlib.pyplot as plt
s_right_train, _, _ = evaluate_skewness(train1[factor_name], factor_name)
s_right_val, _, _ = evaluate_skewness(val1[factor_name], factor_name)
s_right_test, _, _ = evaluate_skewness(test1[factor_name], factor_name)

fig, axes = plt.subplots(1, 3, figsize=(12, 5))


sns.histplot(train1[factor_name], kde=True, ax=axes[0])
axes[0].set_title(f'train data\nSkewness: {s_right_train:.2f}')
sns.histplot(val1[factor_name], kde=True, ax=axes[1])
axes[1].set_title(f'val data \nSkewness: {s_right_val:.2f}')

sns.histplot(test1[factor_name], kde=True, ax=axes[2])
axes[2].set_title(f'test data \nSkewness: {s_right_test:.2f}')

plt.show()
# Out:
# --- rv012_25_5_10_0 偏度分析 ---
# 偏度 (Skewness): -0.0637
# 评估: 分布近似对称 (Approx. Symmetrical)
#
# --- rv012_25_5_10_0 偏度分析 ---
# 偏度 (Skewness): 0.0570
# 评估: 分布近似对称 (Approx. Symmetrical)
#
# --- rv012_25_5_10_0 偏度分析 ---
# 偏度 (Skewness): 0.1150
# 评估: 分布近似对称 (Approx. Symmetrical)

# %%
import pandas as pd
import numpy as np
from scipy.stats import kurtosis, boxcox # boxcox 用于演示转换，尽管对峰度效果有限
from scipy.stats.mstats import winsorize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def evaluate_excess_kurtosis(data_series, feature_name="Feature", name='train'):
    """
    计算数据序列的超额峰度，并根据经验法则进行评估。
    """
    ek = kurtosis(data_series.dropna(), fisher=True, bias=True)
    print(f"超额峰度 (Excess Kurtosis): {ek:.4f}")

    abs_ek = abs(ek)
    if abs_ek < 1:
        interpretation = "尾部行为与正态分布无显著差异 (Mesokurtic-like)"
    elif ek > 0 and 1 <= ek < 3:
        interpretation = "中等程度尖峰/厚尾 (Moderately Leptokurtic)"
    elif ek > 0 and ek >= 3:
        interpretation = "高度尖峰/厚尾 (Highly Leptokurtic / Fat-tailed)"
    elif ek < 0 and -3 < ek <= -1: # 注意这里阈值与之前略有调整，使其更连续
        interpretation = "中等程度平顶/薄尾 (Moderately Platykurtic)"
    elif ek < 0 and ek <= -3:
        interpretation = "高度平顶/薄尾 (Highly Platykurtic)"
    else: # 比如 ek 在 -1 到 0 之间
        interpretation = "轻微平顶/薄尾或接近正态 (Slightly Platykurtic or near Mesokurtic)"

    print(f"{name} 评估: {interpretation}")

    if ek > 1:
        print(f"{name}  提醒: 厚尾意味着极端值出现的概率高于正态分布预期。这对风险管理和某些依赖正态性假设的模型很重要。")
    elif ek < -0.5: # 例如，比-0.5更负
        print(f"{name}  提醒: 薄尾意味着极端值出现的概率低于正态分布预期。数据可能比正态分布更均匀或有界。")
    return ek, interpretation

# %%
ek_original_train, interpretation_original_train = evaluate_excess_kurtosis(train1[factor_name], 
                                                                train1[factor_name].name,
                                                                'train')
ek_original_val, interpretation_original_val = evaluate_excess_kurtosis(val1[factor_name], 
                                                                val1[factor_name].name,
                                                                'val')
ek_original_test, interpretation_original_test = evaluate_excess_kurtosis(test1[factor_name], 
                                                                test1[factor_name].name,
                                                                'test')
# Out:
# 超额峰度 (Excess Kurtosis): 12.6536
# train 评估: 高度尖峰/厚尾 (Highly Leptokurtic / Fat-tailed)
# train  提醒: 厚尾意味着极端值出现的概率高于正态分布预期。这对风险管理和某些依赖正态性假设的模型很重要。
# 超额峰度 (Excess Kurtosis): 0.7558
# val 评估: 尾部行为与正态分布无显著差异 (Mesokurtic-like)
# 超额峰度 (Excess Kurtosis): 0.1409
# test 评估: 尾部行为与正态分布无显著差异 (Mesokurtic-like)

# %%
#plt.figure(figsize=(8, 6))
#sns.histplot(train1[factor_name], kde=True, bins=100) # 增加bins数量以更好观察20万数据的分布
#plt.title(f"feature: {factor_name}\nExcess Kurtosis: {ek_original:.2f} ({interpretation_original})")
#plt.xlabel("Eigenvalue")
#plt.ylabel("Frequency")
#plt.grid(True, which="both", ls="--")
#plt.show()

fig, axes = plt.subplots(1, 3, figsize=(12, 5))
sns.histplot(train1[factor_name], kde=True, bins=100, ax=axes[0]) # 增加bins数量以更好观察20万数据的分布
axes[0].set_title(f'train Excess Kurtosis: {ek_original_train:.2f}')

sns.histplot(val1[factor_name], kde=True, bins=100, ax=axes[1]) # 增加bins数量以更好观察20万数据的分布
axes[1].set_title(f'val Excess Kurtosis: {ek_original_val:.2f}')


sns.histplot(test1[factor_name], kde=True, bins=100, ax=axes[2]) # 增加bins数量以更好观察20万数据的分布
axes[2].set_title(f'test Excess Kurtosis: {ek_original_val:.2f}')

plt.show()
