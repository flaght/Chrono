# %%
import pandas  as pd
import numpy as np
import pdb, os, datetime, itertools, time, hashlib
from lumina.genetic.util import create_id
from dotenv import load_dotenv

load_dotenv()
from lib.flp001 import *

# %%
method = 'bicso2'
task_id = '113001'
instruments = 'rbb'
period = 5

# %%
draft_data = load_data2(method=method, task_id=task_id, instruments=instruments, 
          period=period)
draft_data.head()
# Out:
#   factor_id                                            formula category  \
# 0  10115252  MRes(240,MMinDiff(120,'tc004_10_10_15_1'),MDIF...        d
# 1  10153064  SIGLOG2ABS(MPERCENT(120,SIGLOG10ABS('oi039_2_3...        d
# 2  10568718  MRes(240,MA(240,'tc004_10_10_15_1'),'oi004_5_1...        d
# 3  10392140        MDIFF(90,MDIFF(15,MDIFF(90,'oi039_2_3_1')))        d
# 4  10733688                ASIN(ASIN(MDIFF(5,'oi004_5_10_1')))        d
#
#    direction    source  ic_mean  ann_sharpe  calmar  max_dd  avg_ret  \
# 0         -1  20260325  -0.1577        2.87    3.32  -12.08     0.22
# 1          1  20260325   0.0899        2.81    3.38   -8.75     0.17
# 2         -1  20260325  -0.1661        2.91    3.74  -10.95     0.23
# 3          1  20260325   0.1178        2.93    3.80   -8.82     0.19
# 4         -1  20260325  -0.1805        3.01    3.59  -11.74     0.23
#
#    total_ret  win_rate  pl_ratio  turnover  factor_ac  \
# 0    8308.77     52.07      1.11    0.4355     0.5464
# ...

# %%
draft_data['plot'] = draft_data['plot'].apply(make_clickable)

# %%
# draft_data.to_csv("rbb1.csv",encoding="UTF-8")
draft_data = draft_data[(draft_data['pl_ratio']>= 1.1) & (draft_data['ann_sharpe'] >= 2.5) & (draft_data['calmar'] >= 3)]
draft_data.to_csv("pro_rbb.csv",encoding="UTF-8")

# %%
to_html(draft_data[['plot','direction','formula']])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>plot</th>
#       <th>direction</th>
#       <th>formula</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260325/10115252/evaluation_plot.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260325/10115252/evaluation_plot.png</a></td>
#       <td>-1</td>
#       <td>MRes(240,MMinDiff(120,'tc004_10_10_15_1'),MDIFF(30,'oi004_5_10_1'))</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260325/10153064/evaluation_plot.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260325/10153064/evaluation_plot.png</a></td>
#       <td>1</td>
#       <td>SIGLOG2ABS(MPERCENT(120,SIGLOG10ABS('oi039_2_3_1')))</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...
