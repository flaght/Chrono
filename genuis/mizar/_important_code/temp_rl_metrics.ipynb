# %%
import pandas as pd

# %%
ret_all = pd.read_csv("temp/rl001/results_ret_0.csv")
ret_1000 = pd.read_csv("temp/rl001/results_ret_1000.csv")

# %%
ret_all1 = ret_all.set_index('trade_time')['total_portfolio_return']
ret_all1.name = 'all'

ret_1000_1 = ret_1000.set_index('trade_time')['total_portfolio_return']
ret_1000_1.name = '1000'

# %%
ret_1000_1
# Out:
# trade_time
# 2024-11-19    0.016461
# 2024-11-20    0.019943
# 2024-11-21   -0.011411
# 2024-11-22    0.004509
# 2024-11-25   -0.016292
#                 ...
# 2025-11-04    0.463178
# 2025-11-05    0.467792
# 2025-11-06    0.473590
# 2025-11-07    0.480442
# 2025-11-10    0.480499
# Name: 20, Length: 235, dtype: float64

# %%
pd.concat([ret_1000_1,ret_all1],axis=1).plot()
# Out:
# <Axes: xlabel='trade_time'>

# %%
#ret_abret_market_all = pd.read_csv("temp/rl001/results_abret_market_0.csv")
#ret_abret_market_1000 = pd.read_csv("temp/rl001/results_abret_market_1000.csv")
#abret_abret_market_all = pd.read_csv("temp/rl001/results_abret_market_0_1.csv")
abret_abret_market_1000 = pd.read_csv("temp/rl001/results_abret_market_1000_1.csv")
abret_abret_market_1000_2 = pd.read_csv("temp/rl001/results_abret_market_1000_2.csv")

# %%
#ret_abret_market_all1 = ret_abret_market_all.set_index('trade_time')['total_portfolio_return']
#ret_abret_market_all1.name = 'ret_all'

#ret_abret_market_1000_1 = ret_abret_market_1000.set_index('trade_time')['total_portfolio_return']
#ret_abret_market_1000_1.name = 'ret_1000'


#abret_abret_market_all1 = abret_abret_market_all.set_index('trade_time')['total_portfolio_return']
#abret_abret_market_all1.name = 'abret_all'

abret_abret_market_1000_1 = abret_abret_market_1000.set_index('trade_time')['total_portfolio_return']
abret_abret_market_1000_1.name = 'abret_1000_1'


abret_abret_market_1000_2 = abret_abret_market_1000.set_index('trade_time')['total_portfolio_return']
abret_abret_market_1000_2.name = 'abret_1000_2'

# %%
pd.concat([abret_abret_market_1000_2, abret_abret_market_1000_1],axis=1).plot()
# Out:
# <Axes: xlabel='trade_time'>
