# %%
from IPython.display import display
import pandas as pd
import numpy as np
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
method = 'cicso0'
task_id = '200037'
instruments = 'ims'
period = '15'

# %%
from lib.smx001 import create_plot, create_metrics

# %%
metrics_data = create_metrics(
    method=method,
    instruments=instruments,
    period=period,
    task_id=task_id
)

# %%
count = 60
metrics_data['abs_ic'] = np.abs(metrics_data['ic'])
metrics_data = metrics_data.sort_values(by=['abs_ic','icir','ann_sharpe'],ascending=False).reset_index(drop=True)

names = metrics_data[['name','formula','abs_ic','icir',
                      'ann_sharpe','calmar']].head(count)['name'].to_list()

# %%
draft_data = create_plot(
    method=method,
    instruments=instruments,
    period=period,
    task_id=task_id,
    names=names
)

# %%
metrics_data.formula.to_list()
# Out:
# ["MHMA(120,MCPS(60,'high'))",
#  "MCPS(90,MCPS(120,EMA(120,'close')))",
#  "MDEMA(120,MCPS(120,MADecay(60,'twap')))",
#  "MMASSI(120, MAXIMUM('open', 'close'), 'pct_change')",
#  "MDIFF(240,MMASSI(120,'twap',MADecay(240,'corr_vwap_ask_price_0')))",
#  "MMASSI(120,'twap',MADecay(240,'corr_vwap_ask_price_0'))",
#  "MMASSI(120,'twap',MADecay(240,MDIFF(15,'corr_vwap_ask_price_0')))",
#  "MMASSI(120,'twap',MADecay(240,MADecay(240,'corr_vwap_ask_price_0')))",
#  "MMASSI(120,'twap',MDPO(15,MMAX(15,'corr_vwap_ask_price_0')))",
#  "MMASSI(120,'twap',MADecay(240,MPERCENT(120,'corr_vwap_ask_price_0')))",
#  "MMASSI(120,'twap',MVARIANCE(30,'corr_vwap_ask_price_0'))",
#  "MMASSI(120,'twap',MT3(10,'corr_vwap_ask_price_0'))",
#  "MMASSI(120,'twap',MMIN(5,'corr_vwap_ask_price_0'))",
#  "MMASSI(120,'twap',MPERCENT(120,'corr_vwap_ask_price_0'))",
#  "MMASSI(120,'twap','corr_vwap_ask_price_0')",
# ...

# %%
display(draft_data)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>formula</th>
#       <th>image_path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>40</th>
#       <td>MMASSI(120,FLOOR('twap'),MSmart(60,MT3(10,MPERCENT(30,'corr_money_bid_ask_price_spread')),MARGMIN(240,'volume_order_imbanlace_1')))</td>
#       <td><a target="_blank" href="./records/cicso0/ims/rulex/200037/nxt1_ret_15h/202511107/10007651/comparison_plot.png">./records/cicso0/ims/rulex/200037/nxt1_ret_15h/202511107/10007651/comparison_plot.png</a></td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>MT3(120,MADiff(30,'close'))</td>
#       <td><a target="_blank" href="./records/cicso0/ims/rulex/200037/nxt1_ret_15h/202521112/10094497/comparison_plot.png">./records/cicso0/ims/rulex/200037/nxt1_ret_15h/202521112/10094497/comparison_plot.png</a></td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>MHMA(120,MCPS(60,'high'))</td>
# ...

# %%
selected = [
   "DELTA(90,MMIN(5,MHMA(90,DELTA(90,'high'))))",
 "DELTA(120,MMIN(15,MIR(90,DELTA(90,'high'))))",
 "DELTA(90,MMIN(10,MHMA(90,DELTA(90,'high'))))",
 "MCPS(90,MT3(90,SIGLOG10ABS('high')))",
 "MCPS(60,MA(90,AVG(MCPS(90,'smart_tick_in'))))",
 "MMedian(15,RSI(120,MDEMA(5,MCPS(120,MA(60,'low')))))",
 "MHMA(90,MSUM(30,MCPS(90,'smart_tick_in_pct')))",
 "MIR(90,MDEMA(15,DELTA(90,MMIN(60,DELTA(90,'high')))))",
 "MMIN(60,MMedian(90,MCPS(90,'smart_tick_in')))",
 "MT3(90,MCPS(120,MA(10,'high')))",
 "MQUANTILE(240,EMA(5,MALLTRUE(60,'smart_money_in')))",
 "DELTA(120,MMedian(90,DELTA(90,MMedian(5,'open'))))",
 "MVHF(90,RSI(60,MCPS(120,MA(60,MMAX(10,'twap')))))",
 "MA(60,RSI(90,MCPS(120,MA(60,'twap'))))",
 "MA(60,RSI(90,MCPS(120,MA(60,'open'))))",
 "MIR(120,MDIFF(5,DELTA(90,WMA(60,DELTA(90,'open')))))",
 "DELTA(120,MSKEW(90,DELTA(90,MA(5,'open'))))",
 "MIR(120,MIR(60,DELTA(90,MPERCENT(60,DELTA(90,'close')))))",
 "DELTA(120,MDEMA(90,MADecay(120,DELTA(90,'mid_price_bias_ratio'))))",
 "MMIN(60,WMA(90,MCPS(60,MA(90,'smart_money_in_pct'))))",
 "MA(120,RSI(15,MCPS(120,MA(60,'open'))))",
 "DELTA(90,EMA(90,DELTA(90,MADecay(60,'twap'))))",
 "MIR(90,MDEMA(30,DELTA(90,MMedian(60,DELTA(90,'high')))))",
 "DELTA(90,MMaxDiff(90,DELTA(90,SHIFT(60,'low'))))",
 "MIR(90,MADiff(120,MADecay(90,MDEMA(60,'smart_money_in_pct'))))",
 "DELTA(120,MADecay(60,MA(30,DELTA(90,'open'))))",
 "DELTA(120,DELTA(120,MT3(60,'high')))",
 "MHMA(120,MCPS(60,'smart_money_in_pct'))",
 "MA(10,MT3(90,MCPS(90,MT3(90,'pct_change'))))",
 "MDPO(90,MAPOSITIVE(90,MQUANTILE(90,MSUM(120,WMA(15,'smart_tick_in')))))",
 "MNPOSITIVE(120,DELTA(90,MDPO(120,DELTA(90,WMA(120,'mid_price_bias_ratio')))))",
 "DELTA(120,DELTA(120,EMA(30,WMA(30,WMA(30,'mid_price_bias_ratio')))))",
 "MRANK(120,RSI(30,'pct_change'))",
 "MDPO(10,RSI(30,'pct_change'))",
 "MDPO(10,DELTA(30,'pct_change'))",
 "LOG10(MMIN(30,LOG10(MMedian(120,MIR(30,'smart_tick_in')))))",
 "MADiff(30,MADecay(5,MRANK(60,'corr_money_bid_price_0')))",
 "MA(90,EMA(15,MA(90,MDPO(120,'smart_money_in_pct'))))",
 "MADiff(120,MADecay(240,WMA(90,MDPO(240,'smart_tick_in'))))",
 "MT3(90,MSUM(10,MMaxDiff(120,'twap')))",
 "MSKEW(90,MADiff(120,MADiff(120,MADecay(240,'smart_tick_in'))))",
 "MSUM(15,MA(90,MA(90,DELTA(30,MMaxDiff(60,MA(90,'twap'))))))",
 "MADiff(30,MT3(90,MT3(90,WMA(10,MMaxDiff(120,MMaxDiff(120,'twap'))))))",
 "MCPS(60,MDEMA(60,MT3(120,'mid_price_bias_ratio')))",
 "MMedian(90,MT3(90,MMaxDiff(120,MPERCENT(90,'twap'))))",
 "MPERCENT(240,DELTA(30,'pct_change'))",
 "DELTA(90,MMIN(15,MHMA(90,DELTA(90,'close'))))/MDIFF(90,'close')",
 "DELTA(90,MMIN(10,MHMA(90,DELTA(90,'high'))))/MSTD(90,'high')",
 "DELTA(90,MMIN(5,MHMA(90,DELTA(90,'open'))))/MANYTRUE(90,'open')",
 "DELTA(120,MMIN(10,MMAX(90,DELTA(90,'low'))))/EMA(90,'low')",
 "DELTA(90,MMIN(5,MHMA(90,DELTA(90,'open'))))/MANYTRUE(90,'open')",
 "DELTA(15,RSI(10,MHMA(60,DELTA(60,'low'))))/MSTD(15,'low')",
 "DELTA(120,MMIN(10,MHMA(60,DELTA(60,'low'))))/MSTD(240,'low')",
 "DELTA(90,MMIN(90,MHMA(60,DELTA(60,'low'))))/MSTD(60,'low')",
 "SHIFT(5,MT3(120,MSUM(30,'pct_change')))",
 "MT3(120,MQUANTILE(10,DELTA(120,'pct_change_set')))",
 "MT3(120,MADecay(30,'pct_change'))",
 "MSUM(30,MDIFF(15,MDIFF(15,MT3(120,'pct_change'))))",
 "MADiff(15,MDIFF(240,RSI(30,'pct_change')))",
 "MT3(120,MADiff(30,'close'))",
 "MT3(120,MCPS(60,'low'))",
 "MT3(120,MCPS(30,'high'))",
 "DELTA(120,MADecay(240,MARGMAX(90,DELTA(90,'close'))))",
 "MT3(120,MCPS(60,'high'))",
 "DELTA(120,MMAX(120,DELTA(60,'low')))",
 "MHMA(120,MCPS(60,'high'))",
 "MT3(120,MCPS(30,'close'))",
 "DELTA(90,MADecay(120,MMAX(15,DELTA(90,'low'))))",
 "MT3(120,MCPS(120,'high'))",
 "MT3(120,MPERCENT(90,MT3(90,'pct_change')))",
 "DELTA(90,MHMA(90,DELTA(90,'low')))",
 "DELTA(120,MSUM(90,DELTA(90,'twap')))",
 "DELTA(120,MA(90,DELTA(90,'twap')))",
 "EMA(90,MA(90,MCPS(60,'smart_tick_in')))",
 "MIR(120,MDEMA(120,DELTA(90,MDIFF(60,DELTA(90,'twap')))))",
 "MIR(120,MDEMA(240,DELTA(90,MARGMAX(60,DELTA(90,'twap')))))",
 "MSUM(90,DELTA(120,MA(60,RSI(90,'smart_tick_in'))))",
 "MSUM(120,RSI(60,MCPS(120,MSUM(60,'low'))))",
 "MNPOSITIVE(120,MDEMA(240,DELTA(90,MPERCENT(60,DELTA(90,'close')))))",
 "DELTA(90,WMA(120,DELTA(90,MARGMAX(90,'mid_price_bias'))))",
 "MIR(120,MDEMA(10,DELTA(90,MDIFF(60,DELTA(90,'close')))))",
 "MA(90,MPERCENT(90,MCPS(120,MA(60,'open'))))",
 "MIR(120,MMedian(60,DELTA(90,MPERCENT(60,DELTA(90,'open')))))",
 "MIR(60,MADecay(60,DELTA(120,DELTA(90,'mid_price_bias_ratio'))))",
 "MT3(90,MDPO(90,MT3(90,MA(15,'open'))))",
 "MIR(120,WMA(120,DELTA(90,MPERCENT(60,DELTA(90,'open')))))",
 "MIR(120,MDEMA(120,DELTA(90,MPERCENT(60,DELTA(90,'twap')))))",
 "RSI(120,MCPS(120,MA(90,'low')))",
 "MSUM(120,DELTA(60,MA(90,MCPS(90,'smart_tick_in'))))",
 "MA(60,RSI(120,MCPS(120,MA(60,'twap'))))",
 "MA(120,RSI(30,MCPS(120,MA(60,'high'))))",
 "MA(120,MARGMIN(60,MCPS(120,MA(60,'high'))))",
 "RSI(120,MCPS(120,MA(90,'twap')))",
 "MIR(120,MDEMA(240,DELTA(90,MPERCENT(60,DELTA(90,'close')))))",
 "RSI(120,MCPS(120,MA(90,'pct_change_close')))",
 "MIR(120,MDEMA(240,DELTA(90,RSI(60,DELTA(90,'close')))))",
 "MDPO(20,RSI(30,'pct_change'))",
 "RSI(90,MCPS(120,MMedian(120,'open')))",
 "MT3(120,MDEMA(30,MCPS(90,'high')))",
 "MT3(120,MADiff(90,'high'))",
 "MSKEW(120,MDPO(90,MHMA(90,'smart_money_in')))",
 "RSI(90,MCPS(120,MSUM(120,'high')))",
 "MIR(120,DELTA(90,EMA(90,DELTA(90,'close'))))",
 "DELTA(90,WMA(90,DELTA(90,MA(90,'high'))))",
 "EMA(30,MT3(120,MARGMIN(90,'smart_money_in_pct')))",
 "DELTA(30,MA(90,MSUM(90,DELTA(90,'low'))))",
 "MA(5,MCPS(60,MCPS(120,MA(120,'twap'))))",
 "MSKEW(120,SHIFT(30,MCPS(90,'low')))",
 "DELTA(30,MADecay(90,MCPS(120,MA(120,'high'))))",
 "RSI(120,MCPS(90,MA(90,'pct_change_close')))",
 "MHMA(90,MCPS(120,MA(5,'twap')))",
 "RSI(120,MCPS(120,RSI(120,'pct_change_close')))",
 "DELTA(15,MA(90,MSUM(90,DELTA(90,'low'))))",
 "MCPS(60,MA(90,EMA(90,MCPS(90,'open'))))",
 "DELTA(60,MA(90,MSUM(90,DELTA(90,'high'))))",
 "MT3(90,MCPS(120,MA(30,'high')))",
 "DELTA(60,EMA(90,DELTA(90,MA(90,'twap'))))",
 "MA(120,MADiff(120,MSUM(90,'smart_tick_in_pct')))",
 "MSUM(120,MDEMA(90,MCPS(90,'low')))",
 "RSI(120,MCPS(120,MA(90,'close')))",
 "DELTA(60,MA(90,MSUM(90,DELTA(90,'close'))))",
 "DELTA(10,MT3(90,MMAX(90,DELTA(90,'twap'))))",
 "RSI(120,MCPS(120,MA(60,'pct_change_set')))",
 "RSI(90,MCPS(120,MSUM(120,'low')))",
 "DELTA(30,MA(90,MSUM(90,DELTA(90,'open'))))",
 "MT3(120,MADiff(90,'twap'))",
 "DELTA(15,MQUANTILE(120,SHIFT(60,'open')))",
 "WMA(90,RSI(90,MDEMA(120,'twap')))",
 "DELTA(60,MHMA(90,DELTA(90,MA(90,'twap'))))",
 "DELTA(60,MT3(90,DELTA(90,MA(90,'high'))))",
 "DELTA(60,MA(90,MMAX(90,DELTA(90,'close'))))",
 "MMAX(120,MDEMA(60,MCPS(90,'low')))",
 "DELTA(90,MHMA(10,MCPS(120,MA(120,'low'))))",
 "MIR(120,DELTA(90,MADecay(90,DELTA(90,'twap'))))",
 "DELTA(60,MMedian(90,DELTA(90,MA(90,'twap'))))",
 "MIR(120,MPERCENT(90,DELTA(90,'low')))",
 "DELTA(90,WMA(60,MCPS(120,MA(120,'twap'))))",
 "MDEMA(120,MMIN(90,MDEMA(90,MADiff(90,'high'))))",
 "MDEMA(120,MMIN(90,MDEMA(90,MADiff(90,'high'))))",
 "MA(90,MMedian(60,MCPS(90,'smart_tick_in')))",
 "MADiff(240,MDEMA(90,MNPOSITIVE(90,'smart_money_in_pct')))",
 "DELTA(120,MHMA(120,DELTA(90,'high')))",
 "RSI(90,MCPS(120,MSUM(120,'open')))",
 "DELTA(120,MADecay(90,DELTA(90,MA(90,'high'))))",
 "DELTA(90,MMaxDiff(120,MA(120,'low')))",
 "MDEMA(120,MCPS(120,WMA(90,'twap')))",
 "DELTA(90,RSI(120,'mid_price_bias'))",
 "RSI(90,MMaxDiff(120,MA(120,'pct_change_close')))",
 "MAPOSITIVE(30,MT3(90,MPERCENT(90,MAPOSITIVE(90,'close'))))",
 "MIR(120,DELTA(90,MDEMA(90,DELTA(90,'close'))))",
 "DELTA(90,EMA(90,EMA(90,DELTA(90,'high'))))",
 "DELTA(90,MA(90,MSUM(90,DELTA(90,'low'))))",
 "RSI(90,MCPS(120,MA(120,'low')))",
 "MIR(120,DELTA(90,WMA(90,DELTA(90,'close'))))",
 "MSKEW(120,DELTA(90,MDEMA(90,DELTA(90,'open'))))",
 "DELTA(30,MA(90,MSUM(90,DELTA(90,'high'))))",
 "RSI(90,MCPS(120,MSUM(120,'close')))",
 "DELTA(90,MA(90,MSUM(90,DELTA(90,'open'))))",
 "MHMA(120,RSI(90,MDEMA(60,MCPS(90,'open'))))",
 "MT3(120,MRANK(90,WMA(90,'close')))",
 "RSI(120,MCPS(120,MA(90,'high')))",
 "MIR(120,DELTA(90,MADecay(90,DELTA(90,'high'))))",
 "DELTA(5,MT3(120,MCPS(120,MA(120,'pct_change'))))",
 "MA(120,MADiff(15,EMA(60,MSUM(60,'smart_money_in_pct'))))",
 "MADiff(240,MMedian(120,MDEMA(90,'smart_money_in_pct')))",
 "RSI(120,MT3(120,MA(30,'pct_change')))",
 "MT3(90,MADiff(90,'twap'))",
 "RSI(120,MA(90,RSI(90,'twap')))",
 "DELTA(120,MARGMIN(90,MCPS(120,MA(120,'high'))))",
 "MADiff(120,MMaxDiff(120,MA(120,'pct_change_close')))",
 "MIR(120,DELTA(90,MSKEW(90,DELTA(90,'high'))))",
 "DELTA(120,MA(90,MDEMA(90,DELTA(90,'twap'))))",
 "DELTA(60,MA(90,MSUM(90,DELTA(90,'low'))))",
 "MT3(120,MCPS(90,SHIFT(5,'open')))",
 "RSI(90,DELTA(120,MA(120,'pct_change_close')))",
 "MIR(60,DELTA(90,MSUM(90,DELTA(90,'high'))))",
 "MSKEW(90,MSKEW(90,MDPO(90,MSKEW(90,'pct_change'))))",
 "DELTA(90,MA(90,MSUM(90,DELTA(90,'close'))))",
 "MIR(120,MPERCENT(90,DELTA(90,'twap')))",
 "MIR(15,DELTA(90,MA(90,DELTA(90,'close'))))",
 "MIR(120,DELTA(90,MAPOSITIVE(90,DELTA(90,'high'))))",
 "RSI(120,MCPS(120,EMA(120,'close')))",
 "DELTA(120,MARGMAX(120,MCPS(120,MT3(120,'pct_change'))))",
 "MA(120,DELTA(120,MCPS(90,'twap')))",
 "MT3(90,MADiff(90,'close'))",
 "EMA(90,MCPS(90,MA(120,'smart_tick_in')))",
 "DELTA(60,MA(90,MADecay(90,DELTA(90,'high'))))",
 "WMA(90,MDEMA(90,DELTA(90,'high')))",
 "MMedian(10,MMIN(90,MMedian(90,MADiff(90,'low'))))",
 "DELTA(30,MT3(90,MCPS(120,MA(120,'high'))))",
 "DELTA(120,RSI(120,MCPS(120,MA(120,'pct_change'))))",
 "DELTA(120,MSUM(120,DELTA(90,'high')))",
 "MADecay(120,MAPOSITIVE(90,DELTA(30,'pct_change_close')))",
 "MIR(60,DELTA(90,MA(90,DELTA(90,'pct_change_set'))))",
 "RSI(120,MCPS(120,MDEMA(120,'close')))",
 "MDIFF(30,MT3(120,MCPS(90,'smart_money_in_pct')))",
 "RSI(120,MCPS(120,MA(90,'low')))",
 "MT3(120,MADiff(90,'close'))",
 "DELTA(120,MSUM(90,DELTA(90,'high')))",
 "MIR(120,MPERCENT(90,DELTA(90,'close')))",
 "DELTA(90,MA(90,MSUM(90,DELTA(90,'high'))))",
 "DELTA(60,MA(90,MSUM(90,DELTA(90,'open'))))",
 "MA(90,MMedian(120,MCPS(90,'smart_tick_in_pct')))",
 "DELTA(120,MSKEW(90,MDEMA(90,DELTA(90,'close'))))",
 "MSTD(30,MMIN(15,MMIN(120,MA(120,'pct_change_set'))))",
 "MDEMA(120,MCPS(120,MA(60,'twap')))",
 "MRANK(10,MMIN(60,MADecay(60,'pct_change')))",
 "MSUM(120,MDEMA(90,MCPS(90,'high')))",
 "MSUM(120,DELTA(90,WMA(90,DELTA(90,'low'))))",
 "MDEMA(240,DELTA(90,MDEMA(90,DELTA(90,'high'))))",
 "MIR(15,DELTA(90,MA(90,DELTA(90,'twap'))))",
 "MCPS(60,MA(90,MSUM(90,MCPS(90,'open'))))",
 "RSI(90,MCPS(120,MSUM(120,'twap')))",
 "MDEMA(120,MCPS(120,MADecay(60,'twap')))",
 "SHIFT(10,MT3(120,MCPS(90,'twap')))",
 "DELTA(120,MSUM(90,EMA(90,DELTA(90,'twap'))))",
 "RSI(90,MCPS(120,MAPOSITIVE(120,'low')))",
 "RSI(120,MCPS(120,MADecay(120,'low')))",
 "DELTA(120,MA(90,MSKEW(90,DELTA(90,'low'))))",
 "DELTA(90,MA(90,MSUM(90,DELTA(90,'twap'))))",
 "MDEMA(15,MA(90,MDEMA(90,MADiff(90,'low'))))",
 "DELTA(90,MA(90,MADecay(90,DELTA(90,'open'))))",
 "MT3(120,MADiff(90,'open'))",
 "MT3(120,MADiff(90,'low'))",
 "MIR(120,MPERCENT(90,DELTA(90,'high')))",
 "MSUM(90,WMA(90,MCPS(90,'smart_tick_in')))",
 "MIR(120,DELTA(90,MHMA(90,DELTA(90,'pct_change'))))",
 "MVHF(10,MMASSI(120,MPRO(60,MVHF(10,MPRO(60,'money'))),MAPOSITIVE(10,'twap')))",
 "MT3(90,MDIFF(90,MMaxDiff(120,SIGLOG10ABS('twap'))))",
 "MT3(90,MDIFF(120,MMaxDiff(120,MDIFF(120,MDEMA(10,'twap')))))",
 "MT3(90,MDIFF(90,MMaxDiff(120,SIGLOG10ABS(SIGLOG2ABS('twap')))))",
 "MT3(90,MMaxDiff(120,'twap'))",
 "MQUANTILE(120,RSI(30,'pct_change'))",
 "MT3(90,MCPS(15,MSUM(120,'smart_tick_in')))",
 "MT3(30,MT3(90,MARGMIN(120,'twap')))",
 "MMIN(60,MSLMean(120,'smart_tick_in','order_flow_imbanlace_1'))",
 "MMASSI(120,MCPS(60,'ask_bid_press'),'mid_price_bias_ratio')",
 "MMASSI(120,MPRO(60,MVHF(10,'money')),MAPOSITIVE(10,'twap'))",
 "MT3(120,MCPS(60,'pct_change_set'))",
 "MDPO(120,MT3(90,MT3(90,MCPS(90,'twap'))))",
 "MT3(90,MCPS(90,WMA(90,MCPS(90,'twap'))))",
 "MT3(90,MDIFF(90,MT3(90,MDPO(90,'smart_tick_in'))))",
 "MT3(90,MCPS(90,MDEMA(5,SIGLOG10ABS('twap'))))",
 "MT3(120,MMedian(15,EMA(30,'pct_change')))",
 "MT3(90,MT3(30,MMinDiff(120,'twap')))",
 "MADecay(60,MMIN(15,MT3(90,MCPS(90,'twap'))))",
 "MCPS(120,MT3(90,MMaxDiff(120,'twap')))",
 "MA(120,MT3(90,MADiff(60,MCPS(90,'twap'))))",
 "MT3(90,MSUM(30,MT3(90,DELTA(15,'smart_tick_in'))))",
 "MMaxDiff(120,MT3(90,MMaxDiff(120,'twap')))",
 "MT3(90,MMaxDiff(120,MDIFF(120,'twap')))",
 "MDPO(90,MT3(120,'twap'))",
 "MCPS(90,MSUM(90,MT3(90,MCPS(90,MPRO(15,'twap')))))",
 "MMedian(90,MCPS(120,MMedian(90,'smart_tick_in_pct')))",
 "MT3(90,DELTA(5,MT3(90,MMaxDiff(120,'twap'))))",
 "MRANK(30,MQUANTILE(15,MOD('pct_change','order_flow_imbanlace_avg5')))",
 "MQUANTILE(15,MQUANTILE(15,MQUANTILE(30,MOD('pct_change','order_flow_imbanlace_avg5'))))",
 "DELTA(30,MADiff(15,'pct_change'))",
 "RSI(15, 'pct_change') / MPERCENT(90, RSI(30, 'pct_change'))",
 "MMASSI(120, MINIMUM('money', 'low'), 'pct_change')",
 "MMASSI(120, MAXIMUM('open', 'close'), 'pct_change')",
 "MRANK(60, ADDED(RSI(30, 'pct_change'), RSI(30, 'pct_change')))",
 "MRANK(240, DELTA(30, 'pct_change'))",
 "MPRO(120, MCoef(90, EMA(10, 'close'), 'close'))",
 "MT3(10,SHIFT(60,MMAX(15,MMAX(15,MADiff(60,'mid_price_bias')))))",
 "MCORR(240,MT3(5,'money_in'),MAPOSITIVE(5,'pct_change_set'))",
 "MCORR(240,'money_in',MDEMA(10,'pct_change_set'))",
 "MCORR(240,'money_in',MDIFF(120,'pct_change_set'))",
 "TANH(MCORR(240,'money_in','pct_change_set'))",
 "MCORR(240,'money_in',EMA(5,EMA(5,MADecay(5,MIR(10,'pct_change_set')))))",
 "MMedian(5,MMAX(15,SHIFT(60,MMAX(15,MADiff(60,'mid_price_bias')))))",
 "MADiff(240,SHIFT(60,DELTA(120,DELTA(120,SHIFT(60,'mid_price_bias_ratio')))))",
 "MMedian(5,MCORR(240,'money_in','pct_change_set'))",
 "MSUM(120,MDEMA(60,MDEMA(60,MDEMA(15,MMIN(30,MIR(30,MCPS(60,'smart_tick_out')))))))",
 "MADiff(30,MMAX(15,MDIFF(10,MMAX(15,MMedian(120,'mid_price_bias')))))",
 "MCORR(240,'money_in','pct_change_set')",
 "EMA(5,MCORR(240,'money_in','pct_change_set'))",
 "SHIFT(60,SIGLOG10ABS(MMAX(15,MADiff(60,'mid_price_bias'))))",
 "MSUM(120,MDEMA(60,EMA(5,MPERCENT(240,MDEMA(15,MMIN(30,MVARIANCE(5,'smart_tick_out')))))))",
 "MADecay(120,MRes(5,'pct_change_set','corr_money_bid_price_0'))",
 "MADiff(30,MMAX(15,MDIFF(10,MMAX(15,MMedian(120,MDIFF(10,'mid_price_bias'))))))",
 "MMAX(15,SHIFT(60,MMAX(15,MADiff(60,'mid_price_bias'))))",
 "SHIFT(60,MADiff(60,'mid_price_bias'))",
 "MMASSI(30,MMedian(60,DELTA(90,'smart_volume_out')),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "MMASSI(30,MQUANTILE(120,MMIN(10,'smart_volume_out')),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "MMASSI(30,MARGMIN(10,MA(120,'smart_volume_out')),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "MMASSI(30,MARGMAX(15,MDIFF(5,'smart_volume_out')),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "MMASSI(30,MARGMAX(240,MCPS(60,'smart_volume_out')),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "MMASSI(30,MRANK(60,'smart_volume_out'),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "SHIFT(120,MCORR(90,ABS(EMA(5,'weighted_volume_ask5')),RSI(90,EMA(5,EMA(5,'money_out')))))",
 "MMASSI(30,MARGMAX(240,'smart_volume_out'),MIChimoku(30,MMIN(15,'mid_price_bias'),'delta_volume_bid1'))",
 "MMASSI(30,MDPO(240,'smart_volume_out'),MIChimoku(30,'mid_price_bias','delta_volume_bid1'))",
 "SIGLOGABS(MSUM(60,MADiff(240,SIGLOGABS(WMA(15,CEIL(CEIL(MCPS(90,'mid_price_bias'))))))))",
 "MCORR(50,MQUANTILE(20,'price_imbalance_4'),'corr_money_ask_size_0')",
 "SHIFT(95,'order_imbalance_ratio1')",
 "MADecay(2,MADecay(2,RSI(2,'corr_money_bid_size_0')))",
 "LOG2(MSharp(4,MARGMIN(4,'corr_money_vwap'),'ask_bid_press'))",
 "MADiff(60,MIR(5,'corr_ret_bid_price_0'))",
 "MRes(5,'weighted_volume_ask5','corr_money_ret')",
 "MT3(90,MT3(90,RSI(90,'pct_change')))",
 "MT3(15,SHIFT(60,'net_money_in_pct'))",
 "MDEMA(120,MDEMA(120,DELTA(120,'smart_tick_in')))",
 "EMA(90,DELTA(90,MA(30,'smart_tick_in')))",
 "MDEMA(120,DELTA(120,MDEMA(120,'smart_tick_in')))",
 "MSUM(90,MDIFF(90,DELTA(90,'smart_tick_in')))",
 "MSUM(90,DELTA(90,'smart_tick_in'))",
 "MMAX(15,MDPO(240,EMA(90,'smart_money_in_pct')))",
 "MDPO(90,MARGMAX(120,MSUM(120,'smart_tick_in')))",
 "MMASSI(120,MNPOSITIVE(90,'corr_vwap_ask_price_0'),WMA(5,'smart_tick_in'))",
 "MRes(5,'delta_volume_ask5','corr_money_ret')",
 "MMASSI(90,'twap',MDEMA(10,'order_flow_imbanlace_1'))",
 "MMASSI(90,'twap',MADecay(15,'order_flow_imbanlace_1'))",
 "MMASSI(90,'twap','order_flow_imbanlace_1')",
 "MCPS(60,MT3(120,'mid_price_bias_ratio'))",
 "MMASSI(120,'twap',MADecay(240,MADecay(240,'corr_vwap_ask_price_0')))",
 "MAPOSITIVE(90,MAPOSITIVE(90,RSI(120,'smart_tick_in_pct')))",
 "MDIFF(240,MMASSI(120,'twap',MADecay(240,'corr_vwap_ask_price_0')))",
 "MMASSI(120,'twap',MPERCENT(120,'corr_vwap_ask_price_0'))",
 "MMASSI(120,'twap',MT3(10,'corr_vwap_ask_price_0'))",
 "SHIFT(90,MVHF(15,'ask_bid_press'))",
 "MMASSI(120,MSTD(10,MCPS(120,'pct_change_close')),'smart_tick_in')",
 "MMASSI(120,'twap',MVARIANCE(30,'corr_vwap_ask_price_0'))",
 "MMASSI(120,'twap',MADecay(240,'corr_vwap_ask_price_0'))",
 "MMASSI(120,'twap',MMIN(5,'corr_vwap_ask_price_0'))",
 "MMASSI(120,'twap',MADecay(240,MDIFF(15,'corr_vwap_ask_price_0')))",
 "MMASSI(120,MSUM(5,'twap'),'corr_vwap_ask_price_0')",
 "MADecay(5,MMASSI(120,MT3(5,'corr_vwap_bid_size_0'),'twap'))",
 "MMASSI(120,WMA(30,'pct_change_close'),'smart_tick_in')",
 "MCoef(60,'pct_change_close','tick_out')",
 "MMASSI(120,'pct_change_close','smart_tick_in')",
 "MADiff(120,MADecay(30,MA(90,'smart_tick_in')))",
 "MADiff(120,MADecay(240,MADecay(30,'smart_tick_in')))",
 "MMASSI(120,'twap',MDPO(15,MMAX(15,'corr_vwap_ask_price_0')))",
 "MA(10,MMASSI(120,'twap',MADecay(240,'corr_vwap_ask_price_0')))",
 "MMeanRes(120,'corr_money_bid_size_0',MPRO(15,'smart_tick_in'))",
 "MQUANTILE(240,MT3(120,'smart_money_in'))",
 "MMASSI(120,'twap','corr_vwap_ask_price_0')",
 "MDPO(240,MMeanRes(120,'corr_money_bid_size_0','smart_tick_in'))",
 "MCoef(60,'pct_change_close','tick_out')",
 "MADecay(5,MMASSI(120,'corr_vwap_bid_size_0','twap'))",
 "MMedian(90,MVHF(10,MT3(120,'pct_change')))",
 "MDPO(30,MIR(5,'corr_ret_bid_price_0'))",
 "MSLMean(30,'pct_change','corr_vwap_ret')",
 "MMASSI(120,'twap',MADecay(240,MPERCENT(120,'corr_vwap_ask_price_0')))",
 "MDIFF(120,MSUM(90,RSI(90,'smart_money_in_pct')))",
 "MADiff(60,MT3(120,EMA(240,'pct_change')))",
 "MSUM(90,RSI(90,'smart_money_in_pct'))",
 "MSUM(90,RSI(90,MMinDiff(240,'smart_money_in_pct')))",
 "MIChimoku(60,'order_imbalance_ratio1',DELTA(120,'money_in_pct'))",
 "MMeanRes(60,MSTD(30,'smart_money_out_pct'),MARGMIN(10,'order_flow_imbanlace_avg5'))",
 "MADiff(120,EMA(120,EMA(60,'smart_tick_in_pct')))",
 "ADDED('corr_money_ret','corr_money_bid_size_0')",
 "MConVariance(10,MCPS(5,'net_money_in_pct'),'corr_ret_ask_price_0')",
 "MMASSI(120,MMAX(60,'bid_ask_spread'),'smart_tick_in')",
 "WMA(30,ASIN(MMedian(90,'smart_tick_in_pct')))",
 "MCPS(30,MT3(120,MMedian(60,'smart_tick_in')))",
 "WMA(30,MMedian(90,'smart_tick_in_pct'))",
 "MSUM(5,MADecay(10,MMedian(90,'smart_tick_in_pct')))",
 "EMA(15,MSmart(120,'smart_tick_in','smart_tick_in_pct'))",
 "WMA(60,MT3(90,MCPS(90,'twap')))",
 "MMedian(90,MADecay(10,MT3(5,'smart_tick_in_pct')))",
 "MMeanRes(60,MDEMA(30,'order_imbalance_ratio1'),MADecay(5,'order_imbalance_ratio1'))",
 "MMASSI(120,MIR(120,'corr_ret_ask_size_0'),'smart_tick_in')",
 "MMASSI(120,MMedian(5,'corr_ret_ask_size_0'),'smart_tick_in')",
 "MDIFF(5,MOD('tick_out',MDPO(10,'corr_money_ret')))",
 "MOD('tick_out',MDPO(10,'corr_money_ret'))",
 "MMaxDiff(10,MOD('smart_tick_in_pct',MDEMA(5,'pct_change_close')))",
 "MVHF(5,MNPOSITIVE(5,'corr_money_bid_price_0'))",
 "MOD('tick_out','corr_money_ret')",
 "MIR(10,MCORR(10,'pct_change_set','depth_imbalance_2'))",
 "SHIFT(10,MPERCENT(10,'corr_vwap_ask_size_0'))",
 "MRes(5,'money_in','corr_money_ret')",
 "MADiff(5,MOD('smart_tick_in_pct','pct_change_close'))",
 "MOD(CEIL('tick_out'),'corr_money_ret')",
 "ACOS(MADiff(5,ACOS('corr_money_ret')))",
 "MOD(MDIFF(5,'tick_out'),'corr_money_ret')",
 "MCoef(5,MMaxDiff(5,'tick_out'),MKURT(10,'mid_price_bias_ratio'))",
 "MADiff(5,ADDED('corr_vwap_ask_price_0','corr_money_ret'))",
 "MDPO(10,MOD('tick_out','corr_money_ret'))",
 "SIGMOID(MOD('tick_out','corr_money_ret'))",
 "MMeanRes(5,'log_order_slope','price_imbalance_1')",
 "MOD(AVG('depth_imbalance_3'),RSI(5,'corr_money_vwap'))",
 "DIFF(WMA(5,MADiff(5,'corr_money_ret')))",
 "SUBBED(MCoef(75, 'low', 'open'),MCoef(86, 'low', 'open'))",
 "SHIFT(11, MMASSI(85, 'pct_change_set', 'twap'))",
 "MHMA(120,MCPS(120,MA(60,'pct_change')))",
 "EMA(120,MCPS(90,MA(60,'smart_tick_in')))",
 "MMIN(90,MMedian(60,MCPS(90,'smart_tick_in_pct')))",
 "DELTA(120,DELTA(90,MHMA(90,'mid_price_bias_ratio')))",
 "EMA(30,MADiff(90,MA(90,'smart_tick_in')))",
 "MSKEW(120,MT3(90,MADiff(15,'smart_tick_in')))",
 "DELTA(120,MMASSI(120,'realized_volatility','smart_tick_in'))",
 "EMA(120,MCPS(90,MA(60,'smart_tick_in')))",
 "SHIFT(60,MDPO(240,'twap'))",
 "DELTA(90,MMAX(120,DELTA(60,'pct_change_close')))",
 "DELTA(120,MT3(90,'smart_tick_in'))",
 "MHMA(30,MMedian(60,'smart_volume_in'))",
 "MSKEW(120,MA(90,MCPS(90,'smart_tick_in')))",
 "MHMA(120,MCPS(120,DELTA(60,'pct_change_set')))",
 "DELTA(120,MMAX(90,DELTA(120,'high')))",
 "MA(90,MMedian(120,MCPS(90,'smart_tick_in')))",
 "MSUM(30,MSUM(90,MCPS(90,'smart_tick_in')))",
 "DELTA(120,MMAX(90,DELTA(90,'low')))",
 "RSI(120,MCPS(120,MHMA(60,'low')))",
 "RSI(90,MADiff(120,MSUM(120,'close')))",
 "MCPS(90,MCPS(120,EMA(120,'close')))",
 "EMA(30,MCPS(90,MA(90,'smart_tick_in')))",
 "MT3(90,MADiff(90,'high'))",
 "MDPO(15,MQUANTILE(90,MALLTRUE(90,'smart_volume_in')))",
 "MT3(90,MADiff(90,'low'))",
 "RSI(120,MCPS(120,MMedian(90,'pct_change_set')))",
 "MADiff(240,MA(90,SIGLOG2ABS('smart_money_in_pct')))",
 "MT3(90,MADiff(90,'open'))",
 "DELTA(15,MMedian(15,DELTA(240,'order_flow_imbanlace_1')))",
 "MMeanRes(30,'order_flow_imbanlace_1','pct_change')",
 "MDEMA(30,MRes(30,'order_flow_imbanlace_1',SIGLOG2ABS('pct_change')))",
 "MSmart(30,RSI(30,'corr_ret_bid_price_0'),SIGLOG10ABS('order_flow_imbanlace_avg5'))",
 "MSmart(15,'delta_volume_bid1','corr_ret_bid_price_0')",
 "MCORR(15,'delta_volume_ask5',MPERCENT(30,'order_flow_imbanlace_avg5'))",
 "MQUANTILE(15,MOD('pct_change','order_flow_imbanlace_avg5'))",
 "MMIN(15,MRes(15,'depth_imbalance_4','depth_imbalance_0'))",
 "MSmart(5,'order_flow_imbanlace_weighted5','log_order_slope')",
 "MMeanRes(60,MCORR(90,'corr_money_bid_size_0','smart_tick_out_pct'),MCoef(15,'pct_change_set','mci_ask'))",
 "MRANK(5, MSKEW(30, 'pct_change'))",
 "MRANK(5, DELTA(5, ADDED('price_imbalance_0', 'depth_imbalance_4')))",
 "SIGMOID(MMeanRes(120,'corr_money_bid_size_0','smart_tick_in_pct'))",
 "MMeanRes(120,'corr_money_bid_size_0',SIGLOG2ABS('smart_tick_in_pct'))",
 "MARGMAX(30,MVARIANCE(10,MARGMAX(5,'delta_volume_bid5')))",
 "MDIFF(90,MMeanRes(120,'corr_money_bid_size_0',MAPOSITIVE(5,MDIFF(90,'smart_tick_in_pct'))))",
 "MDIFF(90,MMeanRes(120,'corr_money_bid_size_0','smart_tick_in_pct'))",
 "MMeanRes(120,'corr_money_bid_size_0','smart_tick_in_pct')",
 "SIGLOG10ABS(MDIFF(90,MMeanRes(120,'corr_money_bid_size_0',MDIFF(90,'smart_tick_in_pct'))))",
 "MMeanRes(120,MDIFF(240,'corr_money_bid_size_0'),'smart_tick_in_pct')",
 "MMeanRes(120,'corr_money_bid_size_0',MDIFF(90,'smart_tick_in_pct'))",
 "MMeanRes(120,MDIFF(90,'corr_money_bid_size_0'),'smart_tick_in_pct')",
 "MDIFF(30,MARGMAX(30,MVARIANCE(10,MARGMAX(5,'delta_volume_bid5'))))",
 "MDIFF(90,MDIFF(90,MMeanRes(120,'corr_money_bid_size_0','smart_tick_in_pct')))",
 "MMeanRes(120,TANH('corr_money_bid_size_0'),'smart_tick_in_pct')",
 "MVARIANCE(60,MVHF(120,MA(90,'corr_ret_bid_size_0')))",
 "MMeanRes(10,'delta_volume_bid1',MPERCENT(10,MRANK(120,'corr_vwap_ret')))",
 "MCPS(240,MMIN(90,SIGLOG2ABS('corr_vwap_bid_size_0')))",
 "MCoef(30,MVHF(120,'delta_volume_bid5'),MRANK(90,ROUND('volume_in')))",
 "SHIFT(60,MMAX(15,MADiff(60,'mid_price_bias')))",
 "MPWMA(90,MMaxDiff(10,'price_imbalance_2'),'net_money_in')",
 "MSLMean(30,MRANK(10,MMedian(10,MRANK(120,'corr_ret_ask_size_0'))),'tick_in_pct')",
 "WMA(30,MPWMA(90,'price_imbalance_2','net_money_in'))",
 "MSLMean(30,MRANK(10,MDPO(60,MMedian(10,'corr_ret_ask_size_0'))),'tick_in_pct')",
 "MCoef(30,MVHF(120,'delta_volume_bid5'),ROUND(ROUND('volume_in')))",
 "MCoef(30,MVHF(120,'delta_volume_bid5'),ROUND('volume_in'))",
 "MSLMean(30,MRANK(10,MMedian(10,'corr_ret_ask_size_0')),'tick_in_pct')",
 "EMA(30,MPWMA(90,'price_imbalance_2','net_money_in'))",
 "MMedian(120,MDPO(5,MSUM(30,'mid_price_bias')))",
 "SHIFT(90,SHIFT(60,MCPS(90,MMedian(5,'mid_price_bias_ratio'))))",
 "EMA(30,MPWMA(90,MMaxDiff(90,MDPO(15,'price_imbalance_2')),'net_money_in'))",
 "MCoef(30,MVHF(120,'delta_volume_bid5'),MMIN(240,'volume_in'))",
 "MMIN(5,MPWMA(90,'price_imbalance_2','net_money_in'))",
 "RSI(240,MConVariance(120,'smart_money_in','depth_imbalance_1'))",
 "MA(15,MPWMA(90,'price_imbalance_2','net_money_in'))",
 "SHIFT(90,SHIFT(60,MMedian(5,MQUANTILE(120,'mid_price_bias_ratio'))))",
 "ASIN(MPWMA(240,'log_order_slope','order_imbalance_ratio1'))",
 "SHIFT(90,SHIFT(60,MMedian(5,MQUANTILE(15,'mid_price_bias_ratio'))))",
 "MCORR(240,'money_in',MAPOSITIVE(5,'pct_change_set'))",
 "MAPOSITIVE(30,DELTA(30,'corr_ret_bid_price_0'))",
 "MPWMA(240,MMIN(15,DELTA(10,SHIFT(30,'log_order_slope'))),'order_imbalance_ratio1')",
 "SHIFT(120,MCORR(90,EMA(5,'weighted_volume_ask5'),'money_out'))",
 "MCPS(240,MADecay(15,MT3(120,'smart_money_in')))",
 "MINIMUM(MMedian(15,SIGLOG2ABS('pct_change_set')),SIGLOG2ABS('corr_ret_ask_price_0'))",
 "MVARIANCE(90,MARGMIN(90,'corr_ret_ask_size_0'))",
 "SHIFT(120,EMA(5,MCORR(90,EMA(5,'weighted_volume_ask5'),'money_out')))",
 "MDIFF(15,SHIFT(120,MCORR(90,EMA(5,'weighted_volume_ask5'),'money_out')))",
 "MMIN(30,SHIFT(120,MCORR(90,EMA(5,'weighted_volume_ask5'),'money_out')))",
 "SHIFT(120,MCORR(90,ABS(EMA(5,'weighted_volume_ask5')),'money_out'))",
 "MINIMUM(SIGLOG2ABS(EMA(10,MMAX(10,'pct_change_set'))),'corr_ret_ask_price_0')",
 "SHIFT(120,MDIFF(120,MCORR(90,EMA(5,'weighted_volume_ask5'),'money_out')))"
]

# %%
metrics_data[metrics_data.formula.isin(selected)][['total_return','ann_sharpe','max_drawdown','calmar','ic','icir','turnover','formula']].to_csv("2.csv")
