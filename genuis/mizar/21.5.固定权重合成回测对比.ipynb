# %%
import os
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from lib.bck002 import load_backtest_results

# %%
method = 'ricso2'
instruments = 'rbb'
task_id='113001'
period = 5
param_id = '1098674067525498'
sub_path = 'rollrank2_signal/1002_test'

# %%
res = load_backtest_results(method=method,
                            instruments=instruments,
                            task_id=task_id,
                            sub_path=sub_path,
                            period=period,
                            category='equal_weight')

# %%
pd.concat(res,axis=1).plot(figsize=(14,7))
# Out:
# <Axes: xlabel='date'>
