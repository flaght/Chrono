# %%
import pandas  as pd
import numpy as np
import pdb, os, datetime, itertools, time, hashlib
from dotenv import load_dotenv

load_dotenv()
from lib.flp001 import *

# %%
method = 'bicso3'
task_id = '122001'
session = '20260619'
instruments = 'mab'
period = 15

# %%
results = load_data(method=method, task_id=task_id, instruments=instruments, 
          period=period, session=session, category=2)
results['name'] = results['name'].astype(int).astype(int)
results['abs_ic'] = np.abs(results['ic_mean'])
results['abs_icir'] = np.abs(results['icir'])
results1 = results
results1.tail()
# Out:
# ./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619
#         name                                         expression  avg_ret  \
# 37  10718391                         MPERCENT(90,'tv017_2_5_1')     0.36
# 38  10308180         MMaxDiff(240,MPERCENT(30,'tc014_1_2_5_1'))     0.35
# 39  10689486                      MQUANTILE(90,'tc012_1_2_5_1')     0.35
# 40  10216933  MPERCENT(120,MMaxDiff(240,MCPS(90,'cr042_2_5_1...     0.33
# 41  10587202            MMinDiff(60,MPERCENT(90,'oi037_2_5_1'))     0.26
#
#     total_ret  sharpe  ann_sharpe  max_dd  calmar  win_rate  pl_ratio  ...  \
# 37     502.87    0.02        1.53  -12.81    1.63     52.09      1.10  ...
# 38     441.84    0.02        1.53  -13.49    1.45     51.79      1.10  ...
# 39     497.63    0.02        1.53  -12.81    1.62     52.10      1.10  ...
# 40     445.63    0.02        1.58  -12.25    1.60     51.89      1.09  ...
# 41     264.23    0.02        1.21  -11.99    1.22     51.64      1.08  ...
#
#       icir  turnover  factor_ac  ret_ac  roll_win resampling_win  \
# 37 -0.1787    0.4642    -0.0100 -0.0925      None           None
# 38 -0.1698    0.4579    -0.0574 -0.0924      None           None
# 39 -0.1783    0.4642    -0.0103 -0.0925      None           None
# 40  0.1706    0.4458    -0.0067 -0.0881      None           None
# 41 -0.1538    0.4347    -0.0108 -0.0897      None           None
#
#    holding_profit category  abs_ic  abs_icir
# 37           None        d  0.0484    0.1787
# 38           None        d  0.0457    0.1698
# 39           None        d  0.0483    0.1783
# 40           None        d  0.0455    0.1706
# 41           None        d  0.0413    0.1538
#
# [5 rows x 21 columns]

# %%
# results[results.expression.isin(drafit_data.formula.tolist())].to_csv("rbb_drafit.csv")
results['abs_ic'].median()
# Out:
# 0.041999999999999996

# %%
### IC大于0.03  ## 夏普大于2.2  # 卡玛大于2.5
results = results[(results['abs_ic']>0.04) & (results['ann_sharpe']>1.2) & (
    results['calmar']>1.2)].reset_index(drop=True)

# %%
results
# Out:
#         name                                         expression  avg_ret  \
# 0   10391701   MDIFF(120,SIGLOG10ABS(MRANK(90,'tc006_3_10_1')))     0.39
# 1   10804682          MQUANTILE(90,SIGLOG2ABS('tc014_2_3_5_1'))     0.34
# 2   10618056  MPERCENT(120,MPERCENT(120,MPERCENT(120,'cr042_...     0.32
# 3   10742646        MQUANTILE(240,MQUANTILE(240,'oi039_2_5_1'))     0.33
# 4   10405251                              WMA(30,'dv002_1_3_1')     0.39
# 5   10512288                MCPS(240,MADiff(60,'ixy014_2_5_1'))     0.32
# 6   10630659                MCPS(60,SIGLOG2ABS('oi037_3_10_1'))     0.28
# 7   10967569                         MPERCENT(30,'oi034_2_5_1')     0.35
# 8   10161068                       MQUANTILE(240,'iv012_2_5_1')     0.33
# 9   10987270  MPERCENT(120,ACOS(MPERCENT(120,MCPS(90,'cr042_...     0.33
# 10  10383132  MADiff(240,MQUANTILE(15,MADiff(240,'tn003_1_2_...     0.31
# 11  10094905                   FRAC(MPERCENT(30,'oi034_2_5_1'))     0.35
# 12  10122058  MPERCENT(120,ACOS(MPERCENT(120,MMaxDiff(240,'c...     0.32
# 13  10092195              MPERCENT(90,MCPS(240,'ixy014_2_5_1'))     0.31
# 14  10884841               MPERCENT(120,MCPS(90,'cr042_2_5_1'))     0.33
# 15  10174774       MCPS(240,MDIFF(30,MDIFF(30,'ixy014_2_5_1')))     0.31
# 16  10233714           MRes(60,'rv001_3_10_1_2','ixy014_2_5_1')     0.30
# 17  10740829                       MQUANTILE(240,'oi039_2_5_1')     0.34
# 18  10415811                        MQUANTILE(15,'tv017_2_5_1')     0.30
# 19  10302174  MPERCENT(120,SUBBED('cr003_1_3_1','oi037_3_10_...     0.29
# 20  10443078                              EMA(60,'dv002_1_3_1')     0.40
# 21  10976528                 MCPS(240,MDIFF(30,'ixy014_2_5_1'))     0.31
# 22  10718391                         MPERCENT(90,'tv017_2_5_1')     0.36
# 23  10308180         MMaxDiff(240,MPERCENT(30,'tc014_1_2_5_1'))     0.35
# 24  10689486                      MQUANTILE(90,'tc012_1_2_5_1')     0.35
# 25  10216933  MPERCENT(120,MMaxDiff(240,MCPS(90,'cr042_2_5_1...     0.33
# 26  10587202            MMinDiff(60,MPERCENT(90,'oi037_2_5_1'))     0.26
#
#     total_ret  sharpe  ann_sharpe  max_dd  calmar  win_rate  pl_ratio  ...  \
# 0      610.01    0.02        1.61  -18.35    1.25     51.76      1.10  ...
# 1      455.98    0.02        1.43  -14.52    1.37     51.83      1.09  ...
# 2      393.68    0.02        1.51  -12.23    1.50     51.76      1.09  ...
# 3      445.01    0.02        1.42  -14.92    1.31     52.03      1.09  ...
# 4      623.75    0.02        1.30  -16.43    1.41     51.98      1.09  ...
# 5      410.12    0.02        1.52  -13.11    1.43     52.23      1.09  ...
# 6      313.76    0.02        1.26  -12.82    1.26     52.09      1.08  ...
# 7      442.10    0.02        1.56  -10.48    1.86     51.76      1.10  ...
# 8      434.41    0.02        1.32  -15.85    1.22     51.79      1.08  ...
# 9      447.24    0.02        1.59  -12.11    1.62     51.92      1.09  ...
# 10     406.73    0.02        1.36  -11.77    1.59     51.49      1.09  ...
# 11     442.10    0.02        1.56  -10.48    1.86     51.76      1.10  ...
# 12     411.95    0.02        1.52  -13.88    1.35     51.86      1.09  ...
# 13     357.10    0.02        1.45  -14.03    1.24     51.64      1.09  ...
# 14     443.05    0.02        1.55  -12.36    1.58     51.84      1.09  ...
# 15     398.77    0.02        1.51  -13.25    1.39     52.30      1.09  ...
# 16     378.51    0.02        1.44  -14.22    1.26     51.91      1.09  ...
# 17     460.17    0.02        1.43  -14.44    1.38     52.10      1.09  ...
# 18     300.93    0.02        1.31  -10.34    1.52     51.60      1.09  ...
# 19     333.38    0.02        1.23  -13.16    1.27     51.73      1.08  ...
# 20     640.53    0.02        1.30  -12.49    1.88     52.30      1.09  ...
# 21     398.77    0.02        1.51  -13.25    1.39     52.30      1.09  ...
# 22     502.87    0.02        1.53  -12.81    1.63     52.09      1.10  ...
# 23     441.84    0.02        1.53  -13.49    1.45     51.79      1.10  ...
# 24     497.63    0.02        1.53  -12.81    1.62     52.10      1.10  ...
# 25     445.63    0.02        1.58  -12.25    1.60     51.89      1.09  ...
# 26     264.23    0.02        1.21  -11.99    1.22     51.64      1.08  ...
#
#       icir  turnover  factor_ac  ret_ac  roll_win resampling_win  \
# 0  -0.1599    0.5164     0.0112 -0.0911      None           None
# 1  -0.1691    0.5008    -0.0228 -0.0916      None           None
# 2  -0.1501    0.4450     0.0119 -0.0899      None           None
# 3   0.1658    0.4659     0.0087 -0.0847      None           None
# 4  -0.3821    0.5615     0.3354 -0.0876      None           None
# 5   0.1950    0.4247    -0.0107 -0.0876      None           None
# 6   0.2275    0.4754     0.0160 -0.0861      None           None
# 7  -0.1681    0.4613    -0.0637 -0.0918      None           None
# 8   0.1848    0.5238     0.0153 -0.0863      None           None
# 9  -0.1549    0.4462    -0.0035 -0.0873      None           None
# 10 -0.1587    0.4638    -0.1029 -0.0876      None           None
# 11 -0.1681    0.4613    -0.0637 -0.0918      None           None
# 12  0.1507    0.4459    -0.0034 -0.0899      None           None
# 13  0.1596    0.4423    -0.0140 -0.0937      None           None
# 14  0.1706    0.4459    -0.0077 -0.0884      None           None
# 15  0.2542    0.4183     0.0116 -0.0876      None           None
# 16 -0.2416    0.4188     0.0166 -0.0876      None           None
# 17  0.2056    0.4663     0.0083 -0.0859      None           None
# 18 -0.1534    0.4431    -0.0599 -0.0992      None           None
# 19  0.1543    0.5048     0.0114 -0.0878      None           None
# 20 -0.5934    0.5412     0.6253 -0.0685      None           None
# 21  0.2542    0.4183     0.0116 -0.0876      None           None
# 22 -0.1787    0.4642    -0.0100 -0.0925      None           None
# 23 -0.1698    0.4579    -0.0574 -0.0924      None           None
# 24 -0.1783    0.4642    -0.0103 -0.0925      None           None
# 25  0.1706    0.4458    -0.0067 -0.0881      None           None
# 26 -0.1538    0.4347    -0.0108 -0.0897      None           None
#
#    holding_profit category  abs_ic  abs_icir
# 0            None        d  0.0426    0.1599
# 1            None        d  0.0452    0.1691
# 2            None        d  0.0404    0.1501
# 3            None        d  0.0450    0.1658
# 4            None        d  0.0950    0.3821
# 5            None        d  0.0513    0.1950
# 6            None        d  0.0588    0.2275
# 7            None        d  0.0453    0.1681
# 8            None        d  0.0494    0.1848
# 9            None        d  0.0416    0.1549
# 10           None        d  0.0428    0.1587
# 11           None        d  0.0453    0.1681
# 12           None        d  0.0404    0.1507
# 13           None        d  0.0424    0.1596
# 14           None        d  0.0456    0.1706
# 15           None        d  0.0667    0.2542
# 16           None        d  0.0638    0.2416
# 17           None        d  0.0553    0.2056
# 18           None        d  0.0413    0.1534
# 19           None        d  0.0404    0.1543
# 20           None        d  0.1426    0.5934
# 21           None        d  0.0667    0.2542
# 22           None        d  0.0484    0.1787
# 23           None        d  0.0457    0.1698
# 24           None        d  0.0483    0.1783
# 25           None        d  0.0455    0.1706
# 26           None        d  0.0413    0.1538
#
# [27 rows x 21 columns]

# %%
results = results[['expression','name']]
results['path'] = (base_path + '/' + str(method) + '/' + instruments + '/rulex' + '/' + str(task_id) + "/nxt1_ret_{0}h".format(period) \
    + "/d{0}".format(session) + '/plot/' + + results['name'].astype(str) + '.png')
                   
results['path'] = results['path'].apply(make_clickable)

# %%
### IC大于 total ic 0.017
to_html(results)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>expression</th>
#       <th>name</th>
#       <th>path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>MDIFF(120,SIGLOG10ABS(MRANK(90,'tc006_3_10_1')))</td>
#       <td>10391701</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10391701.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10391701.png</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MQUANTILE(90,SIGLOG2ABS('tc014_2_3_5_1'))</td>
#       <td>10804682</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10804682.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10804682.png</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>MPERCENT(120,MPERCENT(120,MPERCENT(120,'cr042_2_5_1')))</td>
#       <td>10618056</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10618056.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10618056.png</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MQUANTILE(240,MQUANTILE(240,'oi039_2_5_1'))</td>
#       <td>10742646</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10742646.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10742646.png</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>WMA(30,'dv002_1_3_1')</td>
#       <td>10405251</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10405251.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10405251.png</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>MCPS(240,MADiff(60,'ixy014_2_5_1'))</td>
#       <td>10512288</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10512288.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10512288.png</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>MCPS(60,SIGLOG2ABS('oi037_3_10_1'))</td>
#       <td>10630659</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10630659.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10630659.png</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>MPERCENT(30,'oi034_2_5_1')</td>
#       <td>10967569</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10967569.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10967569.png</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>MQUANTILE(240,'iv012_2_5_1')</td>
#       <td>10161068</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10161068.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10161068.png</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>MPERCENT(120,ACOS(MPERCENT(120,MCPS(90,'cr042_2_5_1'))))</td>
#       <td>10987270</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10987270.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10987270.png</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>MADiff(240,MQUANTILE(15,MADiff(240,'tn003_1_2_5_5_1')))</td>
#       <td>10383132</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10383132.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10383132.png</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>FRAC(MPERCENT(30,'oi034_2_5_1'))</td>
#       <td>10094905</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10094905.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10094905.png</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>MPERCENT(120,ACOS(MPERCENT(120,MMaxDiff(240,'cr042_2_5_1'))))</td>
#       <td>10122058</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10122058.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10122058.png</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>MPERCENT(90,MCPS(240,'ixy014_2_5_1'))</td>
#       <td>10092195</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10092195.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10092195.png</a></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>MPERCENT(120,MCPS(90,'cr042_2_5_1'))</td>
#       <td>10884841</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10884841.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10884841.png</a></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>MCPS(240,MDIFF(30,MDIFF(30,'ixy014_2_5_1')))</td>
#       <td>10174774</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10174774.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10174774.png</a></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>MRes(60,'rv001_3_10_1_2','ixy014_2_5_1')</td>
#       <td>10233714</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10233714.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10233714.png</a></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>MQUANTILE(240,'oi039_2_5_1')</td>
#       <td>10740829</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10740829.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10740829.png</a></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>MQUANTILE(15,'tv017_2_5_1')</td>
#       <td>10415811</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10415811.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10415811.png</a></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>MPERCENT(120,SUBBED('cr003_1_3_1','oi037_3_10_1'))</td>
#       <td>10302174</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10302174.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10302174.png</a></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>EMA(60,'dv002_1_3_1')</td>
#       <td>10443078</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10443078.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10443078.png</a></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>MCPS(240,MDIFF(30,'ixy014_2_5_1'))</td>
#       <td>10976528</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10976528.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10976528.png</a></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>MPERCENT(90,'tv017_2_5_1')</td>
#       <td>10718391</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10718391.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10718391.png</a></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MMaxDiff(240,MPERCENT(30,'tc014_1_2_5_1'))</td>
#       <td>10308180</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10308180.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10308180.png</a></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>MQUANTILE(90,'tc012_1_2_5_1')</td>
#       <td>10689486</td>
#       <td><a target="_blank" href="./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10689486.png">./records/bicso3/mab/rulex/122001/nxt1_ret_15h/d20260619/plot/10689486.png</a></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>MPERCENT(120,MMaxDiff(240,M

# %%
results1.sort_values(by=['icir'],ascending=False).max()
# Out:
# name                                    10989681
# expression        WMA(5,MDIFF(15,'tv007_1_2_1'))
# avg_ret                                     0.25
# total_ret                               11492.64
# sharpe                                      0.03
# ann_sharpe                                  3.11
# max_dd                                     -8.86
# calmar                                      2.87
# win_rate                                   52.32
# pl_ratio                                    1.12
# ic_mean                                   0.0607
# icir                                      0.2293
# turnover                                  0.4569
# factor_ac                                 0.9687
# ret_ac                                   -0.0686
# roll_win                                    None
# resampling_win                              None
# holding_profit                              None
# category                                       d
# abs_ic                                    0.0848
# abs_icir                                  0.3218
# dtype: object
