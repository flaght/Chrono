# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.bcp001.plot001 import *

# %%
method = 'ricso2'
instruments= 'rbb'
task_id = '113001'
period = '5'
category = 'test'

# %%
param1 = Params(composite_method='rl',
                composite_id='1018806311332385',
                singal_method='erband_signal',
                signal_id='1002',
                model_id='1018806311332385',
                backtest_id = '1013836755991964'
                )

param2 = Params(composite_method='equal_weight',
                composite_id='7',
                singal_method='rollrank2_signal',
                signal_id='1002',
                model_id='2018806311332385',
                backtest_id = '1013836755991964'
                )

# %% [markdown]
# #### ER值绩效对比

# %%
plot_mode_er_metrics1(method, instruments, task_id, period, category,
                          left_params=param1, right_params=param2)

# %% [markdown]
# #### 信号值绩效对比

# %%
plot_mode_signal_metrics1(method=method, instruments=instruments, 
                          task_id=task_id, 
                          period=period, 
                          category=category,
                          left_params=param1, 
                          right_params=param2)

# %% [markdown]
# #### 回测绩效对比

# %%
plot_mode_backtest_metrics1(method=method, instruments=instruments, 
                          task_id=task_id, 
                          period=period, 
                          category=category,
                          left_params=param1, 
                          right_params=param2)
# Out:
#                                      total_pnl  annual_return  \
# name
# test_rl_1018806311332385            34515.8894         0.2859
# test_equal_weight_2018806311332385  36977.0924         0.3031
#
#                                     annual_volatility  sharpe_ratio  \
# name
# test_rl_1018806311332385                        0.081        3.1465
# test_equal_weight_2018806311332385              0.077        3.4787
#
#                                     calmar_ratio  max_drawdown  long_trades  \
# name
# test_rl_1018806311332385                  6.9456       -0.0412      34.1217
# test_equal_weight_2018806311332385        7.5370       -0.0402      26.8311
#
#                                     short_trades
# name
# test_rl_1018806311332385                 34.1293
# test_equal_weight_2018806311332385       26.8197
