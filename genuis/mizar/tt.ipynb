# %%
from dotenv import load_dotenv

load_dotenv()
from kdutils.data import *

# %%
fetch_metrics(category='research', 
              code='RB', 
              name="MADecay(30,'oi039_1_2_1')", 
              begin_time="2026-05-01 09:00:00", 
              end_time="2026-05-22 09:00:00", 
              table_name="ic_series")
# Out:
# {'category': 'research', 'code': 'RB', 'name': "MADecay(30,'oi039_1_2_1')", 'datetime': {'$gte': '2026-05-01 09:00:00', '$lte': '2026-05-22 09:00:00'}} ic_series
# Empty DataFrame
# Columns: []
# Index: []
