# %%
#%matplotlib widget
import matplotlib.pyplot as plt
from PIL import Image

# %%
img1 = Image.open('/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/final/rl/1018806311332385/metrics/plot/test.png')
img2 = Image.open('/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/proto/rl/1018806311332385/erband_signal/metrics/plot/1002_test.png')

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
axes[0].imshow(img1)
axes[0].set_title('Image A: Before') # 设置标题
axes[0].axis('off')                  # 隐藏坐标轴（可选）

# 4. 在右边显示第二张图
axes[1].imshow(img2)
axes[1].set_title('Image B: After')
axes[1].axis('off')
plt.tight_layout()
plt.show()

# %%
from IPython.display import HTML, display
img_path1 = '/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/final/rl/1018806311332385/metrics/plot/test.png'
img_path2 = '/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/proto/rl/1018806311332385/erband_signal/metrics/plot/1002_test.png'
# 使用 HTML 代码并排显示
html_str = f"""
<div style="display: flex; flex-direction: row; justify-content: space-around;">
    <div style="text-align: center;">
        <h3>图片 1</h3>
        <img src="{img_path1}" style="width: 400px; border: 1px solid black;" />
    </div>
    <div style="text-align: center;">
        <h3>图片 2</h3>
        <img src="{img_path2}" style="width: 400px; border: 1px solid black;" />
    </div>
</div>
"""

display(HTML(html_str))
# Out:
# <div style="display: flex; flex-direction: row; justify-content: space-around;">
#     <div style="text-align: center;">
#         <h3>图片 1</h3>
#         <img src="/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/final/rl/1018806311332385/metrics/plot/test.png" style="width: 400px; border: 1px solid black;" />
#     </div>
#     <div style="text-align: center;">
#         <h3>图片 2</h3>
#         <img src="/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/proto/rl/1018806311332385/erband_signal/metrics/plot/1002_test.png" style="width: 400px; border: 1px solid black;" />
#     </div>
# </div>

# %% [markdown]
# <p float="left">
#   <img src="/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/final/rl/1018806311332385/metrics/plot/test.png" width="400" />
#   <img src="/workspace/worker/pj/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/signal/proto/rl/1018806311332385/erband_signal/metrics/plot/1002_test.png" width="400" />
# </p>

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.bcp001.plot001 import *

# %%
method = 'ricso2'
instruments= 'rbb'
task_id = '113001'
period = '5'
composite_method = 'rl'
composite_id = '1018806311332385'
singal_method= 'erband_signal'
signal_id = '1002'
model_id = '1018806311332385'
backtest_id = '1013836755991964'

# %%
plot_algo_backtest_metrics1(method=method, 
                            instruments=instruments, 
                            task_id=task_id, 
                            period=period,
                            composite_method=composite_method, 
                            composite_id=composite_id, 
                            singal_method=singal_method,
                            signal_id=signal_id, 
                            model_id=model_id, 
                            category='test', 
                            backtest_id=backtest_id)
# Out:
#                       total_pnl  annual_return  annual_volatility  \
# name
# proto_backtest_test  95624.6775         0.6689             0.2322
# final_backtest_test  34515.8894         0.2859             0.0810
#
#                      sharpe_ratio  calmar_ratio  max_drawdown  long_trades  \
# name
# proto_backtest_test        2.3230        6.6343       -0.1008     254.8422
# final_backtest_test        3.1465        6.9456       -0.0412      34.1217
#
#                      short_trades
# name
# proto_backtest_test      254.8992
# final_backtest_test       34.1293

# %%
plot_algo_er_metrics1(method=method, 
                      instruments=instruments, 
                      task_id=task_id, 
                      period=period, 
                      model_id=model_id,
                      composite_method=composite_method, 
                      composite_id=composite_id, 
                      category='test')

# %%
plot_algo_signal_metrics1(method=method,
               instruments=instruments,
               task_id=task_id,
               period=period,
               composite_method=composite_method,
               composite_id=composite_id,
               singal_method=singal_method,
               signal_id=signal_id,
               model_id = model_id,
               category='test')
