# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'cicso0'
instruments = 'ims'
period = 5
task_id = '200037'
session = '202509226'

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id, session=session, category='valid')
# Out:
#                        name  \
# 0   ultron_1062599446314421
# 1   ultron_1014282301313791
# 2   ultron_1088671997371758
# 3   ultron_1088341927890943
# 4   ultron_1015740189138241
# 5   ultron_1000189163636328
# 6   ultron_1001091950930296
# 7   ultron_1025689852065747
# 8   ultron_1009639345092646
# 9   ultron_1083028740537606
# 10  ultron_1051035074154809
# 11  ultron_1018551132937462
# 12  ultron_1074524556959974
# 13  ultron_1009101290986794
# 14  ultron_1092263205219850
# 15  ultron_1016682007299494
# 16  ultron_1027298902581841
# 17  ultron_1079192925654607
# 18  ultron_1089334020751955
# 19  ultron_1023871638374920
# 20  ultron_1034803700054044
# 21  ultron_1054134921045860
# 22  ultron_1016443238498894
# 23  ultron_1088734317249687
# 24  ultron_1052511474217775
# 25  ultron_1093006444355723
# 26  ultron_1040608220257122
# 27  ultron_1039367943701772
#
#                                               formual  final_fitness
# 0     WMA(4,MUL('smart_tick_in',MT3(2,'pct_change')))       0.028214
# 1                        DELTA(4,RSI(4,'pct_change'))       0.027557
# 2   MADecay(3,RSI(3,MDEMA(3,MDEMA(3,SIGLOG10ABS('p...       0.027523
# 3                        MDIFF(3,MT3(3,'pct_change'))       0.027522
# 4                                 MT3(3,'pct_change')       0.027522
# 5   MADecay(3,MDEMA(3,MDEMA(3,SIGLOG10ABS('pct_cha...       0.027327
# 6            DELTA(3,DELTA(3,'mid_price_bias_ratio'))       0.026971
# 7                           MT3(3,ACOS('pct_change'))       0.026565
# 8                            DELTA(3,DELTA(3,'twap'))       0.026351
# 9     MMedian(2,MDPO(4,MDPO(2,MAPOSITIVE(3,'twap'))))       0.025863
# 10                       WMA(2,RSI(3,MDPO(4,'twap')))       0.025819
# 11                  MT3(2,MDPO(4,'pct_change_close'))       0.025786
# 12                   MADecay(3,MDEMA(3,'pct_change'))       0.025515
# 13  DELTA(3,MADiff(2,MAPOSITIVE(4,'mid_price_bias_...       0.025502
# 14              SIGLOG2ABS(DELTA(3,'pct_change_set'))       0.025485
# 15                          DELTA(3,'pct_change_set')       0.025481
# 16     MA(4,MDPO(3,MADiff(3,'mid_price_bias_ratio')))       0.025398
# 17                         MT3(2,MT3(2,'pct_change'))       0.025137
# 18                    RSI(4,MCPS(4,'pct_change_set'))       0.024645
# 19           RSI(4,MDIFF(4,MCPS(4,'pct_change_set')))       0.024645
# 20                     MDEMA(3,DELTA(4,'pct_change'))       0.024221
# 21                                RSI(4,'pct_change')       0.024178
# 22  MA(2,MA(2,SIGLOG2ABS(MADiff(2,'pct_change_clos...       0.023695
# 23  MDIFF(3,MDPO(4,MDPO(2,MAPOSITIVE(3,SIGLOG2ABS(...       0.023626
# 24                       MSUM(2,MSUM(2,'pct_change'))       0.023560
# 25               MDPO(4,MDPO(2,MAPOSITIVE(3,'twap')))       0.023482
# 26      MDIFF(3,MDPO(4,MDPO(2,MAPOSITIVE(3,'twap'))))       0.023482
# 27  MADiff(4,MADecay(3,MDPO(3,MADecay(3,RSI(3,'twa...       0.022621

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id,session=session, category='valid').loc[23]['formual']
# Out:
# "MDIFF(3,MDPO(4,MDPO(2,MAPOSITIVE(3,SIGLOG2ABS('twap')))))"
