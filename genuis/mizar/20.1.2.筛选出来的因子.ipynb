# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'cicso0'
instruments = 'ims'
period = 15
session = '202509229'

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 load_programs(method=method, instruments=instruments, period=period, session=session, category='valid')
#
# File /workspace/worker/pj/Chrono/genuis/mizar/lib/iux002.py:36, in load_programs(method, instruments, period, session, category)
#      30 dirs = os.path.join(base_path, method, instruments, category, 'ic',
#      31                     "nxt1_ret_{}h".format(str(period)), str(session))
#      32 filename = os.path.join(
#      33     dirs, "programs_{0}_{1}.feather".format(
#      34         INDEX_MAPPING[INSTRUMENTS_CODES[instruments]], str(session)))
# ---> 36 programs = pd.read_feather(filename)
#      38 programs = programs[programs['final_fitness'] > 0.02][[
#      39     'name', 'formual', 'final_fitness'
#      40 ]]
#      41 return programs
#
# File /workspace/worker/env/lingua/lib/python3.8/site-packages/pandas/io/feather_format.py:128, in read_feather(path, columns, use_threads, storage_options)
#     125 import_optional_dependency("pyarrow")
#     126 from pyarrow import feather
# --> 128 with get_handle(
#     129     path, "rb", storage_options=storage_options, is_text=False
#     130 ) as handles:
#     132     return feather.read_feather(
#     133         handles.handle, columns=columns, use_threads=bool(use_threads)
#     134     )
#
# File /workspace/worker/env/lingua/lib/python3.8/site-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './records/cicso0/ims/valid/ic/nxt1_ret_15h/202509229/programs_200036_202509229.feather'

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid').loc[15]['formual']
# Out:
# "MDEMA(2,MCPS(3,MCPS(3,MDEMA(4,'pct_change_close'))))"
