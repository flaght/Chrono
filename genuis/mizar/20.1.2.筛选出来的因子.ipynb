# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'bicso0'
instruments = 'rbb'
period = 5
task_id = '113001'
session = '202510208'

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id, session=session, category='valid')
# Out:
#                       name                                            formual  \
# 0  ultron_1759924563087452  SUBBED(MCPS(14,RSI(4,'oi003_2_3_1')),'tn002_1_0')
# 1  ultron_1759932729952949                              MSUM(4,'gd003_1_2_0')
# 2  ultron_1760001461053354                           MMedian(4,'gd003_1_2_0')
# 3  ultron_1760059772794749                             MDPO(10,'iv012_2_3_0')
# 4  ultron_1759920709842258                MDPO(14,MPERCENT(10,'iv012_2_3_0'))
# 5  ultron_1760016631833902                              MDPO(6,'iv012_2_3_0')
# 6  ultron_1760059497107442                  MDPO(10,MADiff(10,'iv012_2_3_0'))
# 7  ultron_1760020278912182  MSUM(2,MADiff(8,MPERCENT(10,MSUM(2,'tv018_1_2_...
# 8  ultron_1760026059145616               EXP(MPERCENT(10,EXP('iv008_2_3_0')))
# 9  ultron_1759939774495226                           MRANK(10,'ixy012_2_3_0')
#
#    final_fitness
# 0       0.030326
# 1       0.028959
# 2       0.026895
# 3       0.026741
# 4       0.026621
# 5       0.024812
# 6       0.023355
# 7       0.022664
# 8       0.022641
# 9       0.022521

# %%
load_programs(method=method, instruments=instruments, period=period, 
              task_id=task_id,session=session, category='valid').loc[7]['formual']
# Out:
# "MSUM(2,MADiff(8,MPERCENT(10,MSUM(2,'tv018_1_2_0'))))"
