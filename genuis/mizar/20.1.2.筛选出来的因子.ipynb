# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'cicso0'
instruments = 'ims'
period = 15
task_id = '200037'
session = '202510317'

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id, session=session, category='valid')
# Out:
#                       name                                            formual  \
# 0  ultron_1010899686479232  MMeanRes(240,RSI(90,'money'),MCoef(15,'money',...
#
#    final_fitness
# 0       0.044832

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id,
              session=session, category='valid').loc[0]['formual']
# Out:
# "MMeanRes(240,RSI(90,'money'),MCoef(15,'money','smart_money_in'))"
