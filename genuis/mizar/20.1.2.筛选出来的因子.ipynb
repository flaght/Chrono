# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'aicso0'
instruments = 'ims'
period = 5
session = '202509221'

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid')
# Out:
#                        name  \
# 0   ultron_1018396741528302
# 1   ultron_1007909726392868
# 2   ultron_1023004163377039
# 3   ultron_1047504440271036
# 4   ultron_1092460367424761
# 5   ultron_1758614904161040
# 6   ultron_1089820508045153
# 7   ultron_1050640747039775
# 8   ultron_1758615006609230
# 9   ultron_1063816188148987
# 10  ultron_1007843359956665
# 11  ultron_1089695314578281
# 12  ultron_1027690818179495
# 13  ultron_1096174088766553
# 14  ultron_1758631951290844
# 15  ultron_1091546719736549
# 16  ultron_1032689284477530
# 17  ultron_1005625741373925
# 18  ultron_1758616807138006
# 19  ultron_1061645478571152
# 20  ultron_1758632454072787
# 21  ultron_1054134921045860
# 22  ultron_1085965737261965
# 23  ultron_1052181987071739
# 24  ultron_1095745322454668
# 25  ultron_1017198000449803
# 26  ultron_1030208453610149
# 27  ultron_1015377720613060
#
#                                               formual  final_fitness
# ...

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid').loc[3]['formual']
# Out:
# "MDIFF(4,DIFF(MDEMA(4,MINIMUM('mid_price_bias_ratio','pct_change_set'))))"
