# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'bicso0'
instruments = 'rbb'
period = 5
session = '20250919'

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid')
# Out:
#                        name                                        formual  \
# 0   ultron_1758313278343772            TANH(TANH(MDIFF(20,'tc003_2_3_0')))
# 1   ultron_1758313245277382                      TANH(TANH('tc003_2_3_0'))
# 2   ultron_1758313201863550       SIGLOGABS(TANH(MDIFF(20,'tc003_2_3_0')))
# 3   ultron_1758313249446800        TANH(MDIFF(20,MDIFF(20,'tc003_2_3_0')))
# 4   ultron_1758312971808512                  TANH(MDIFF(20,'tc003_2_3_0'))
# 5   ultron_1758312497522813                            TANH('tc003_2_3_0')
# 6   ultron_1758318389168356                  MMedian(4,ABS('gd003_1_2_0'))
# 7   ultron_1758317760848220                       MMedian(4,'gd003_1_2_0')
# 8   ultron_1758318210461482                       MMedian(4,'gd003_1_2_1')
# 9   ultron_1758314666661892           MDIFF(14,MPERCENT(12,'tc003_2_3_0'))
# 10  ultron_1758304351366676      WMA(2,WMA(2,MQUANTILE(10,'tc003_1_2_0')))
# 11  ultron_1758319992501395  MQUANTILE(10,MDIFF(8,MDIFF(8,'tc003_2_3_0')))
# 12  ultron_1758320146864836  MDIFF(8,MQUANTILE(10,MDIFF(8,'tc003_2_3_0')))
# 13  ultron_1758319650210860           MQUANTILE(10,MDIFF(8,'tc003_2_3_0'))
#
#     final_fitness
# 0        0.030437
# 1        0.030437
# 2        0.030352
# 3        0.030137
# 4        0.030137
# 5        0.030137
# 6        0.026895
# 7        0.026895
# 8        0.026150
# 9        0.026006
# 10       0.025135
# 11       0.022781
# 12       0.022781
# 13       0.022781

# %%
load_programs(method=method, instruments=instruments, period=period, session=session, category='valid').loc[3]['formual']
# Out:
# "MDIFF(4,DIFF(MDEMA(4,MINIMUM('mid_price_bias_ratio','pct_change_set'))))"
