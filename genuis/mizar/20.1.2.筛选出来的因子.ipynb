# %%
import pandas as pd
import os
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.iux002 import load_programs

# %%
method = 'cicso0'
instruments = 'ims'
period = 15
task_id = '200037'
session = '202511111'#'202510217'
category = 'eligible'

# %%
programs_data = load_programs(method=method, instruments=instruments, period=period, 
            task_id=task_id, session=session, 
            category='valid')
programs_data.head()
# Out:
#                       name  \
# 0  ultron_1011330578749430
# 1  ultron_1023690571256408
# 2  ultron_1027171705340724
# 3  ultron_1015821814091351
# 4  ultron_1004616332283764
#
#                                                                                        formual  \
# 0  MMASSI(120,MARGMAX(90,MNPOSITIVE(240,RSI(240,RSI(240,MVHF(10,'money'))))),MDEMA(30,'twap'))
# 1            RELU(MMASSI(120,MARGMAX(15,RSI(240,MVHF(10,MVHF(10,'money')))),MDEMA(30,'twap')))
# 2                  MMASSI(120,MDEMA(30,MADiff(90,RSI(240,MVHF(10,'money')))),MDEMA(30,'twap'))
# 3                         MMASSI(120,MQUANTILE(60,RSI(240,MVHF(10,'money'))),MDEMA(30,'twap'))
# 4                            MMASSI(120,RSI(240,MVHF(10,'money')),MDEMA(30,MDIFF(240,'twap')))
#
#    final_fitness
# 0       0.134002
# 1       0.133785
# 2       0.133494
# 3       0.133467
# 4       0.133463

# %%
import re
search_string = "MT3(90,DELTA"
escaped_string = re.escape(search_string)
programs_data['is_target'] = programs_data['formual'].str.contains(escaped_string, na=False)
sorted_df = programs_data[programs_data['is_target']]
sorted_df#.head()
# Out:
#                         name  \
# 96   ultron_1008894818466398
# 110  ultron_1075666076194511
#
#                                                 formual  final_fitness  \
# 96        MT3(90,DELTA(5,MT3(90,MMaxDiff(120,'twap'))))       0.035699
# 110  MT3(90,MSUM(30,MT3(90,DELTA(15,'smart_tick_in'))))       0.028393
#
#      is_target
# 96        True
# 110       True

# %%
load_programs(method=method, instruments=instruments, period=period, task_id=task_id,
              session=session, category='valid').loc[20]['formual']
# Out:
# "MA(5,MAPOSITIVE(120,MA(5,MQUANTILE(90,MA(5,MA(5,MA(5,MA(5,MQUANTILE(90,'twap')))))))))"
