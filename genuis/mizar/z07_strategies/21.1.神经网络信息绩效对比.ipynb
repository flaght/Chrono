# %%
import pandas as pd
import os
import pyprojroot, sys
from pyprojroot.criterion import has_file
sys.path.insert(0, str(pyprojroot.find_root(has_file("pyproject.toml"))))

from dotenv import load_dotenv,find_dotenv

# load_dotenv()

env_file_path = find_dotenv()
print("当前加载的 .env 文件路径:", env_file_path)
# 2. 加载该文件
load_dotenv(env_file_path, override=True)
# Out:
# 当前加载的 .env 文件路径: /workspace/worker/kdwk/Chrono/genuis/mizar/.env
# True

# %%
from lib.flp001 import load_signal_performance,to_html1
# Out:
# /workspace/worker/kdwk/Chrono/genuis/mizar
# /workspace/worker/kdwk/Chrono/genuis/mizar/config/contract.toml

# %%
results = load_signal_performance(
    "/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite"
)

# %%
results1 = results[['signal_method','signal_id','model','code','data_type','ann_sharpe','calmar','win_rate','pl_ratio','plot']]
results1
# Out:
#               signal_method signal_id      model code data_type  ann_sharpe  \
# 0   linear_threshold_signal      1204   ensemble   HC       测试集        0.34
# 1   linear_threshold_signal      1204   ensemble   RB       测试集        0.84
# 2   linear_threshold_signal      1204  seed_2026   HC       测试集        0.04
# 3   linear_threshold_signal      1204  seed_2026   RB       测试集        1.59
# 4   linear_threshold_signal      1204  seed_3407   HC       测试集        0.67
# 5   linear_threshold_signal      1204  seed_3407   RB       测试集        0.59
# 6   linear_threshold_signal      1204    seed_42   HC       测试集        0.48
# 7   linear_threshold_signal      1204    seed_42   RB       测试集        0.86
# 8          threshold_signal      1304   ensemble   HC       测试集        0.14
# 9          threshold_signal      1304   ensemble   RB       测试集        0.50
# 10         threshold_signal      1304  seed_2026   HC       测试集       -0.15
# 11         threshold_signal      1304  seed_2026   RB       测试集        1.79
# 12         threshold_signal      1304  seed_3407   HC       测试集        0.65
# 13         threshold_signal      1304  seed_3407   RB       测试集        0.19
# 14         threshold_signal      1304    seed_42   HC       测试集        0.24
# 15         threshold_signal      1304    seed_42   RB       测试集        0.79
#
#     calmar  win_rate  pl_ratio  \
# 0     0.56    0.5174      1.02
# 1     1.78    0.5194      1.06
# 2     0.04    0.5232      1.00
# 3     3.20    0.5227      1.11
# 4     1.44    0.5134      1.05
# 5     1.18    0.5158      1.04
# 6     0.79    0.5192      1.03
# 7     1.62    0.5205      1.06
# 8     0.22    0.5214      1.01
# 9     0.90    0.5228      1.05
# 10   -0.19    0.5159      0.99
# 11    4.67    0.5428      1.17
# 12    1.20    0.5169      1.05
# 13    0.22    0.5094      1.01
# 14    0.35    0.5255      1.02
# 15    1.45    0.5202      1.07
#
#                                                  plot
# 0   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 1   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 2   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 3   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 4   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 5   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 6   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 7   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 8   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 9   /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 10  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 11  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 12  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 13  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 14  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...
# 15  /workspace/worker/kdwk/Chrono/genuis/mizar/rec...

# %%
results1 = to_html1(results=results1, u_name='plot', k_name=['signal_method','signal_id','model','code'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>signal_method</th>
#       <th>signal_id</th>
#       <th>model</th>
#       <th>code</th>
#       <th>data_type</th>
#       <th>ann_sharpe</th>
#       <th>calmar</th>
#       <th>win_rate</th>
#       <th>pl_ratio</th>
#       <th>plot</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>ensemble</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.34</td>
#       <td>0.56</td>
#       <td>0.5174</td>
#       <td>1.02</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/ensemble/linear_threshold_signal/1204/HC_linear_threshold_signal_1204_test/evaluation_plot.png">10137911</a></td>
#       <td>10137911</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>ensemble</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.84</td>
#       <td>1.78</td>
#       <td>0.5194</td>
#       <td>1.06</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/ensemble/linear_threshold_signal/1204/RB_linear_threshold_signal_1204_test/evaluation_plot.png">10224997</a></td>
#       <td>10224997</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_2026</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.04</td>
#       <td>0.04</td>
#       <td>0.5232</td>
#       <td>1.00</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_2026/linear_threshold_signal/1204/HC_linear_threshold_signal_1204_test/evaluation_plot.png">10662939</a></td>
#       <td>10662939</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_2026</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>1.59</td>
#       <td>3.20</td>
#       <td>0.5227</td>
#       <td>1.11</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_2026/linear_threshold_signal/1204/RB_linear_threshold_signal_1204_test/evaluation_plot.png">10712164</a></td>
#       <td>10712164</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_3407</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.67</td>
#       <td>1.44</td>
#       <td>0.5134</td>
#       <td>1.05</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_3407/linear_threshold_signal/1204/HC_linear_threshold_signal_1204_test/evaluation_plot.png">10829242</a></td>
#       <td>10829242</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_3407</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.59</td>
#       <td>1.18</td>
#       <td>0.5158</td>
#       <td>1.04</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_3407/linear_threshold_signal/1204/RB_linear_threshold_signal_1204_test/evaluation_plot.png">10496025</a></td>
#       <td>10496025</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_42</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.48</td>
#       <td>0.79</td>
#       <td>0.5192</td>
#       <td>1.03</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_42/linear_threshold_signal/1204/HC_linear_threshold_signal_1204_test/evaluation_plot.png">10968270</a></td>
#       <td>10968270</td>
#     </tr>
#     <tr>
#       <td>linear_threshold_signal</td>
#       <td>1204</td>
#       <td>seed_42</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.86</td>
#       <td>1.62</td>
#       <td>0.5205</td>
#       <td>1.06</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_42/linear_threshold_signal/1204/RB_linear_threshold_signal_1204_test/evaluation_plot.png">10070661</a></td>
#       <td>10070661</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>ensemble</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.14</td>
#       <td>0.22</td>
#       <td>0.5214</td>
#       <td>1.01</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/ensemble/threshold_signal/1304/HC_threshold_signal_1304_test/evaluation_plot.png">10288979</a></td>
#       <td>10288979</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>ensemble</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.50</td>
#       <td>0.90</td>
#       <td>0.5228</td>
#       <td>1.05</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/ensemble/threshold_signal/1304/RB_threshold_signal_1304_test/evaluation_plot.png">10801347</a></td>
#       <td>10801347</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_2026</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>-0.15</td>
#       <td>-0.19</td>
#       <td>0.5159</td>
#       <td>0.99</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_2026/threshold_signal/1304/HC_threshold_signal_1304_test/evaluation_plot.png">10353066</a></td>
#       <td>10353066</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_2026</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>1.79</td>
#       <td>4.67</td>
#       <td>0.5428</td>
#       <td>1.17</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_2026/threshold_signal/1304/RB_threshold_signal_1304_test/evaluation_plot.png">10838729</a></td>
#       <td>10838729</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_3407</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.65</td>
#       <td>1.20</td>
#       <td>0.5169</td>
#       <td>1.05</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_3407/threshold_signal/1304/HC_threshold_signal_1304_test/evaluation_plot.png">10360625</a></td>
#       <td>10360625</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_3407</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.19</td>
#       <td>0.22</td>
#       <td>0.5094</td>
#       <td>1.01</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_3407/threshold_signal/1304/RB_threshold_signal_1304_test/evaluation_plot.png">10298730</a></td>
#       <td>10298730</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_42</td>
#       <td>HC</td>
#       <td>测试集</td>
#       <td>0.24</td>
#       <td>0.35</td>
#       <td>0.5255</td>
#       <td>1.02</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_42/threshold_signal/1304/HC_threshold_signal_1304_test/evaluation_plot.png">10009278</a></td>
#       <td>10009278</td>
#     </tr>
#     <tr>
#       <td>threshold_signal</td>
#       <td>1304</td>
#       <td>seed_42</td>
#       <td>RB</td>
#       <td>测试集</td>
#       <td>0.79</td>
#       <td>1.45</td>
#       <td>0.5202</td>
#       <td>1.07</td>
#       <td><a href="/workspace/worker/kdwk/Chrono/genuis/mizar/records/ricso2/rbb/temp/model/113001/5/rl/composite/seed_42/threshold_signal/1304/RB_threshold_signal_1304_test/evaluation_plot.png">10882733</a></td>
#       <td>10882733</td>
#     </tr>
#   </tbody>
# </table>

# %%
results1
