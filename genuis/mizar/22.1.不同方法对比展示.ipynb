# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.bcp001.plot001 import *

# %% [markdown]
# ### 强化学习

# %%
method = 'ricso2'
instruments= 'rbb'
task_id = '113001'
period = '5'


composite_method = 'rl'
composite_id = '1018806311332385'
singal_method= 'erband_signal'
signal_id = '1002'
model_id = '1018806311332385'
backtest_id = '1013836755991964'

# %% [markdown]
# #### 合成值绩效

# %%
plot_algo_er_metrics1(method=method, 
                      instruments=instruments, 
                      task_id=task_id, 
                      period=period, 
                      model_id=model_id,
                      composite_method=composite_method, 
                      composite_id=composite_id, 
                      category='test')

# %% [markdown]
# #### 合成值转信号绩效

# %%
plot_algo_signal_metrics1(method=method,
               instruments=instruments,
               task_id=task_id,
               period=period,
               composite_method=composite_method,
               composite_id=composite_id,
               singal_method=singal_method,
               signal_id=signal_id,
               model_id = model_id,
               category='test')

# %% [markdown]
# #### 回测值绩效

# %%
plot_algo_backtest_metrics1(method=method, 
                            instruments=instruments, 
                            task_id=task_id, 
                            period=period,
                            composite_method=composite_method, 
                            composite_id=composite_id, 
                            singal_method=singal_method,
                            signal_id=signal_id, 
                            model_id=model_id, 
                            category='test', 
                            backtest_id=backtest_id)
# Out:
#                       total_pnl  annual_return  annual_volatility  \
# name
# proto_backtest_test  95624.6775         0.6689             0.2322
# final_backtest_test  34515.8894         0.2859             0.0810
#
#                      sharpe_ratio  calmar_ratio  max_drawdown  long_trades  \
# name
# proto_backtest_test        2.3230        6.6343       -0.1008     254.8422
# final_backtest_test        3.1465        6.9456       -0.0412      34.1217
#
#                      short_trades
# name
# proto_backtest_test      254.8992
# final_backtest_test       34.1293

# %% [markdown]
# ### 固定权重

# %%
method = 'ricso2'
instruments= 'rbb'
task_id = '113001'
period = '5'
composite_method = 'equal_weight'
composite_id = '7'
singal_method= 'rollrank2_signal'
signal_id = '1002'
model_id = '2018806311332385'
backtest_id = '1013836755991964'

# %% [markdown]
# #### 合成值绩效

# %%
plot_algo_er_metrics1(method=method, 
                      instruments=instruments, 
                      task_id=task_id, 
                      period=period, 
                      model_id=model_id,
                      composite_method=composite_method, 
                      composite_id=composite_id, 
                      category='test')

# %% [markdown]
# #### 合成值转信号绩效

# %%
plot_algo_signal_metrics1(method=method,
               instruments=instruments,
               task_id=task_id,
               period=period,
               composite_method=composite_method,
               composite_id=composite_id,
               singal_method=singal_method,
               signal_id=signal_id,
               model_id = model_id,
               category='test')

# %% [markdown]
# #### 回测值绩效

# %%
plot_algo_backtest_metrics1(method=method, 
                            instruments=instruments, 
                            task_id=task_id, 
                            period=period,
                            composite_method=composite_method, 
                            composite_id=composite_id, 
                            singal_method=singal_method,
                            signal_id=signal_id, 
                            model_id=model_id, 
                            category='test', 
                            backtest_id=backtest_id)
# Out:
#                        total_pnl  annual_return  annual_volatility  \
# name
# proto_backtest_test  108301.5195         0.7351             0.2472
# final_backtest_test   36977.0924         0.3031             0.0770
#
#                      sharpe_ratio  calmar_ratio  max_drawdown  long_trades  \
# name
# proto_backtest_test        2.3553        3.7537       -0.1958     319.7799
# final_backtest_test        3.4787        7.5370       -0.0402      26.8311
#
#                      short_trades
# name
# proto_backtest_test      319.8463
# final_backtest_test       26.8197
