# %%
import datetime
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from lib.attr001.ftd001 import *
from ultron.tradingday import *
# Out:
# /workspace/worker/env/lingua/lib/python3.8/site-packages/Finance_Jindowin-1.5.4-py3.8.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /workspace/worker/env/lingua/lib/python3.8/site-packages/Finance_Jindowin-1.5.4-py3.8.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /workspace/worker/env/lingua/lib/python3.8/site-packages/Finance_Jindowin-1.5.4-py3.8.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /workspace/worker/env/lingua/lib/python3.8/site-packages/Finance_Jindowin-1.5.4-py3.8.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# ...

# %%
mongo_client = MongoDBManager(uri=os.environ['MG_URI'])

# %%
end_time=datetime.datetime(2026,6,30)
begin_time=datetime.datetime(2026,6,26)#advanceDateByCalendar("china.sse", end_time, "-5b")
category=['bench','trader','research']
end_time1 = advanceDateByCalendar("china.sse", end_time, "1b")

# %%
metrics_data = fetch_factors_metrics(
    mongo_client=mongo_client,
    category=category,
    code='RB', begin_time=begin_time, 
                      end_time=end_time1,
                      names="MDEMA(120,'tc004_1_1_2_0')")
# Out:
# {'code': 'RB', 'trade_time': {'$gte': datetime.datetime(2026, 6, 26, 0, 0), '$lte': datetime.datetime(2026, 7, 1, 0, 0)}, 'category': {'$in': ['bench', 'trader', 'research']}, 'name': {'$in': ["MDEMA(120,'tc004_1_1_2_0')"]}}

# %%
#metrics_data[metrics_data['category'] == 'research']

# %%
#metrics_data[metrics_data['trade_time'] <' 2026-06-01']

# %%
_ = plot_timesies(data=metrics_data, values='ic')

# %%
metrics_data = fetch_factors_metrics(
    mongo_client=mongo_client,
    category=category,
    code='RB', begin_time=begin_time, 
                      end_time=end_time1,
                      names="EMA(30,SIGMOID('iv012_2_3_1'))")
# Out:
# {'code': 'RB', 'trade_time': {'$gte': datetime.datetime(2026, 6, 26, 0, 0), '$lte': datetime.datetime(2026, 7, 1, 0, 0)}, 'category': {'$in': ['bench', 'trader', 'research']}, 'name': {'$in': ["EMA(30,SIGMOID('iv012_2_3_1'))"]}}

# %%
_ = plot_timesies(data=metrics_data, values='ic')

# %%
metrics_data = fetch_factors_metrics(
    mongo_client=mongo_client,
    category=category,
    code='RB', begin_time=begin_time, 
                      end_time=end_time1,
                      names="EMA(5,'tc004_1_1_2_0')")

_ = plot_timesies(data=metrics_data, values='ic')
# Out:
# {'code': 'RB', 'trade_time': {'$gte': datetime.datetime(2026, 6, 26, 0, 0), '$lte': datetime.datetime(2026, 7, 1, 0, 0)}, 'category': {'$in': ['bench', 'trader', 'research']}, 'name': {'$in': ["EMA(5,'tc004_1_1_2_0')"]}}

# %%
metrics_data = fetch_factors_metrics(
    mongo_client=mongo_client,
    category=category,
    code='RB', begin_time=begin_time,
                      end_time=end_time1,
                      names="WMA(10,'tv004_1_2_0')")

_ = plot_timesies(data=metrics_data, values='ic')
# Out:
# {'code': 'RB', 'trade_time': {'$gte': datetime.datetime(2026, 6, 26, 0, 0), '$lte': datetime.datetime(2026, 7, 1, 0, 0)}, 'category': {'$in': ['bench', 'trader', 'research']}, 'name': {'$in': ["WMA(10,'tv004_1_2_0')"]}}

# %%
metrics_data = fetch_factors_metrics(
    mongo_client=mongo_client,
    category=category,
    code='RB', begin_time=begin_time, 
                      end_time=end_time1,
                      names="EMA(5,MDIFF(15,'tv007_1_2_1'))")

_ = plot_timesies(data=metrics_data, values='ic')
# Out:
# {'code': 'RB', 'trade_time': {'$gte': datetime.datetime(2026, 6, 26, 0, 0), '$lte': datetime.datetime(2026, 7, 1, 0, 0)}, 'category': {'$in': ['bench', 'trader', 'research']}, 'name': {'$in': ["EMA(5,MDIFF(15,'tv007_1_2_1'))"]}}
