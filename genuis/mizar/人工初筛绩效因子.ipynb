# %%
import pandas  as pd
import numpy as np
import pdb, os, datetime, itertools, time, hashlib
from dotenv import load_dotenv

load_dotenv()
from lib.flp001 import *

# %%
method = 'bicso2'
task_id = '113001'
session = '20260421'
instruments = 'rbb'
period = 5

# %%
results = load_data(method=method, task_id=task_id, instruments=instruments, 
          period=period, session=session, category=2)
results['name'] = results['name'].astype(int).astype(int)
results['abs_ic'] = np.abs(results['ic_mean'])
results['abs_icir'] = np.abs(results['icir'])
results1 = results
results1.tail()
# Out:
#         name                                         expression  avg_ret  \
# 77  10776332              MRANK(120,MMaxDiff(90,'oi004_2_3_1'))     0.16
# 78  10151575                         MDIFF(90,'ixy007_10_15_1')     0.22
# 79  10522409  ADDED('oi039_2_3_1',MRANK(240,MRANK(240,'oi039...     0.17
# 80  10630309       MDEMA(5,SIGLOG10ABS(MDEMA(5,'iv012_2_3_1')))     0.18
# 81  10538193            MADiff(120,MMinDiff(240,'oi039_2_3_1'))     0.18
#
#     total_ret  sharpe  ann_sharpe  max_dd  calmar  win_rate  pl_ratio  ...  \
# 77    2417.47    0.02        2.51   -8.40    3.31     51.89      1.10  ...
# 78    8182.17    0.03        2.80  -12.00    3.33     52.22      1.10  ...
# 79    2947.25    0.03        2.77  -10.15    2.93     52.46      1.11  ...
# 80    3206.01    0.02        2.45  -11.42    2.67     51.76      1.10  ...
# 81    3604.33    0.03        2.73   -9.20    3.44     51.90      1.11  ...
#
#       icir  turnover  factor_ac  ret_ac  roll_win resampling_win  \
# 77 -0.1732    0.4110     0.4069  0.0268      None           None
# 78 -0.7457    0.4109     0.7334  0.0339      None           None
# 79  0.3651    0.4110     0.0365  0.0335      None           None
# 80  0.3873    0.4781    -0.0455  0.0328      None           None
# 81  0.2955    0.4071     0.6506  0.0334      None           None
#
#    holding_profit category  abs_ic  abs_icir
# 77           None        d  0.0473    0.1732
# 78           None        d  0.1786    0.7457
# 79           None        d  0.0934    0.3651
# 80           None        d  0.0971    0.3873
# 81           None        d  0.0784    0.2955
#
# [5 rows x 21 columns]

# %%
# drafit_data = pd.read_csv("/workspace/worker/pj/Chrono/genuis/mizar/records/bicso2/rbb/rulex/113001/nxt1_ret_5h/draft.csv")
# drafit_data

# %%
# results[results.expression.isin(drafit_data.formula.tolist())].to_csv("rbb_drafit.csv")

# %%
### IC大于0.03  ## 夏普大于2.2  # 卡玛大于2.5
results = results[(results['abs_ic']>0.03) & (results['ann_sharpe']>2.2) & (
    results['calmar']>2.8)].reset_index(drop=True)

# %%
results = results[['expression','name']]
results['path'] = (base_path + '/' + str(method) + '/' + instruments + '/rulex' + '/' + str(task_id) + "/nxt1_ret_{0}h".format(period) \
    + "/d{0}".format(session) + '/plot/' + + results['name'].astype(str) + '.png')
                   
results['path'] = results['path'].apply(make_clickable)

# %%
### IC大于0.03  ## 夏普大于2.2  # 卡玛大于2.5
to_html(results)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>expression</th>
#       <th>name</th>
#       <th>path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>EXP(EMA(60,'oi039_2_3_1'))</td>
#       <td>10158299</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10158299.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10158299.png</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>TANH('oi039_2_3_1')</td>
#       <td>10726396</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10726396.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10726396.png</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SIGMOID(SIGMOID(MDPO(10,SIGLOG10ABS('tc021_1_2_1'))))</td>
#       <td>10865783</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10865783.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10865783.png</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MRANK(240,'oi039_2_3_1')</td>
#       <td>10184113</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10184113.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10184113.png</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>SIGLOG10ABS('oi039_1_2_1')</td>
#       <td>10450368</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10450368.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10450368.png</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>MDIFF(30,'oi004_1_2_1')</td>
#       <td>10898255</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10898255.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10898255.png</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ADDED('oi034_5_10_1',MDEMA(15,MMAX(15,'oi039_2_3_1')))</td>
#       <td>10918821</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10918821.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10918821.png</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>MPERCENT(240,FRAC('oi004_2_3_1'))</td>
#       <td>10427302</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10427302.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10427302.png</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>MA(10,'ixy007_1_2_1')</td>
#       <td>10886457</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10886457.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10886457.png</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>MDIFF(60,'iv012_5_10_1')</td>
#       <td>10420983</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10420983.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10420983.png</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>MMaxDiff(90,WMA(5,MDIFF(15,'oi004_2_3_1')))</td>
#       <td>10247666</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10247666.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10247666.png</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>MDEMA(5,'iv012_2_3_1')</td>
#       <td>10855344</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10855344.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10855344.png</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>MDIFF(30,WMA(5,SIGLOG2ABS('oi004_2_3_1')))</td>
#       <td>10444524</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10444524.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10444524.png</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>MRANK(240,ADDED('oi039_2_3_1','oi039_2_3_1'))</td>
#       <td>10040609</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10040609.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10040609.png</a></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>MADiff(60,'oi035_10_15_1')</td>
#       <td>10969624</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10969624.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10969624.png</a></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>ADDED('oi039_2_3_1',MMaxDiff(120,'oi039_2_3_1'))</td>
#       <td>10194580</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10194580.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10194580.png</a></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>MADecay(5,MDEMA(5,'iv012_2_3_1'))</td>
#       <td>10565957</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10565957.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10565957.png</a></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>MMaxDiff(90,SIGMOID('dv002_2_3_1'))</td>
#       <td>10579458</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10579458.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10579458.png</a></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>MDIFF(5,'oi039_2_3_1')</td>
#       <td>10827279</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10827279.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10827279.png</a></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>MDIFF(90,'oi034_10_15_1')</td>
#       <td>10613479</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10613479.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10613479.png</a></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>MDIFF(60,MDIFF(60,'iv012_5_10_1'))</td>
#       <td>10176570</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10176570.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10176570.png</a></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>SIGLOG10ABS('oi039_2_3_1')</td>
#       <td>10481397</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10481397.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10481397.png</a></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>SIGLOG2ABS(SIGLOG2ABS(WMA(5,'oi004_2_3_1')))</td>
#       <td>10810102</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10810102.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10810102.png</a></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MDEMA(5,SIGLOG10ABS('oi034_10_15_1'))</td>
#       <td>10372961</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10372961.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10372961.png</a></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>SIGLOG10ABS('tv004_10_15_1')</td>
#       <td>10001623</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10001623.png">./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10001623.png</a></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>ADDED('oi039_2_3_1','oi039_2_3_1')</td>
#       <td>10210952</td>
#       <td><a target="_blank" href="./records/bicso2/rbb/rulex/113001/nxt1_ret_5h/d20260421/plot/10210952.png">./records/bicso2/rbb/rulex/113001/nxt1_r

# %%
results1.sort_values(by=['icir'],ascending=False).max()
# Out:
# name                                    10995411
# expression        WMA(90,MDPO(60,'oi004_2_3_1'))
# avg_ret                                     0.24
# total_ret                               12370.71
# sharpe                                      0.03
# ann_sharpe                                  3.19
# max_dd                                     -6.95
# calmar                                      4.77
# win_rate                                   53.01
# pl_ratio                                    1.13
# ic_mean                                   0.2763
# icir                                      1.1921
# turnover                                  0.4879
# factor_ac                                  0.976
# ret_ac                                    0.0385
# roll_win                                    None
# resampling_win                              None
# holding_profit                              None
# category                                       d
# abs_ic                                    0.2763
# abs_icir                                  1.1921
# dtype: object
